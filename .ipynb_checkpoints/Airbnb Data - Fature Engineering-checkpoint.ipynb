# %% [markdown]
# ## Feature Engineering

# %%
# Import pandas library
import pandas as pd

# %%
#Read scrapped data file
#open airbnb_hawai_data.csv file from appropriate folder
Airbnbdata = pd.read_csv(r'C:/Users/pooja/OneDrive/Desktop/AirBnb - Web Scraping & Data Analysis/Airbnb_WebScrap_Data.csv').drop('Unnamed: 0',axis='columns')
Airbnbdata
# Out:
#                       listing_Location  \
# 0    Entire rental unit in Kailua-Kona
# 1         Entire home in Mountain View
# 2          Entire bungalow in Pepeekeo
# 3          Entire rental unit in Kihei
# 4       Entire guest suite in Honolulu
# ..                                 ...
# 295            Entire loft in Honolulu
# 296             Entire cottage in Paia
# 297           Entire condo in Honolulu
# 298              Entire condo in Kihei
# 299            Entire condo in Lahaina
#
#                                           Listing_Name  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...
# 2             Heavenly Hakalau: Oceanfront Cliff House
# 3        3 minutes walk to the beach 2BR/2BA Top floor
# 4                      Honolulu Hale with free parking
# ..                                                 ...
# 295  Unique opportunity to rent a New York style loft!
# 296                     LunaHouse In The Heart of Paia
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean
#
#                                        Features  \
# 0      8 guests · 3 bedrooms · 5 beds · 3 baths
# 1      8 guests · 3 bedrooms · 3 beds · 2 baths
# 2      4 guests · 2 bedrooms · 2 beds · 2 baths
# 3      4 guests · 2 bedrooms · 3 beds · 2 baths
# 4       6 guests · 2 bedrooms · 2 beds · 1 bath
# ..                                          ...
# 295  6 guests · 2 bedrooms · 2 beds · 1.5 baths
# 296     4 guests · 2 bedrooms · 2 beds · 1 bath
# 297     5 guests · 2 bedrooms · 3 beds · 1 bath
# 298    4 guests · 2 bedrooms · 2 beds · 2 baths
# 299    6 guests · 2 bedrooms · 3 beds · 2 baths
#
#                                    Price       Rating_Review
# 0                                ,&nbsp;  4.87 (187 reviews)
# 1    $332 CAD per night, originally $358  4.96 (217 reviews)
# 2                     $742 CAD per night  4.97 (154 reviews)
# 3                     $496 CAD per night  4.85 (171 reviews)
# 4                     $379 CAD per night  4.83 (124 reviews)
# ..                                   ...                 ...
# 295  $834 CAD per night, originally $904   4.72 (18 reviews)
# 296  $466 CAD per night, originally $504    5.0 (74 reviews)
# 297                   $419 CAD per night               empty
# 298                   $635 CAD per night    4.60 (5 reviews)
# 299                   $788 CAD per night   4.88 (52 reviews)
#
# [300 rows x 5 columns]

# %%
#Seprate the area of accomodation from 'Type_of_Accomordation' text
#split the text using 'in' word
Airbnbdata_R1 = Airbnbdata['listing_Location'].str.split('in', expand=True)
Airbnbdata_R1

#After Splitting we want to drop the actual column
Airbnbdata = Airbnbdata.drop(['listing_Location'],axis=1)
Airbnbdata
# Out:
#                                           Listing_Name  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...
# 2             Heavenly Hakalau: Oceanfront Cliff House
# 3        3 minutes walk to the beach 2BR/2BA Top floor
# 4                      Honolulu Hale with free parking
# ..                                                 ...
# 295  Unique opportunity to rent a New York style loft!
# 296                     LunaHouse In The Heart of Paia
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean
#
#                                        Features  \
# 0      8 guests · 3 bedrooms · 5 beds · 3 baths
# 1      8 guests · 3 bedrooms · 3 beds · 2 baths
# 2      4 guests · 2 bedrooms · 2 beds · 2 baths
# 3      4 guests · 2 bedrooms · 3 beds · 2 baths
# 4       6 guests · 2 bedrooms · 2 beds · 1 bath
# ..                                          ...
# 295  6 guests · 2 bedrooms · 2 beds · 1.5 baths
# 296     4 guests · 2 bedrooms · 2 beds · 1 bath
# 297     5 guests · 2 bedrooms · 3 beds · 1 bath
# 298    4 guests · 2 bedrooms · 2 beds · 2 baths
# 299    6 guests · 2 bedrooms · 3 beds · 2 baths
#
#                                    Price       Rating_Review
# 0                                ,&nbsp;  4.87 (187 reviews)
# 1    $332 CAD per night, originally $358  4.96 (217 reviews)
# 2                     $742 CAD per night  4.97 (154 reviews)
# 3                     $496 CAD per night  4.85 (171 reviews)
# 4                     $379 CAD per night  4.83 (124 reviews)
# ..                                   ...                 ...
# 295  $834 CAD per night, originally $904   4.72 (18 reviews)
# 296  $466 CAD per night, originally $504    5.0 (74 reviews)
# 297                   $419 CAD per night               empty
# 298                   $635 CAD per night    4.60 (5 reviews)
# 299                   $788 CAD per night   4.88 (52 reviews)
#
# [300 rows x 4 columns]

# %%
#Combine the dataframes
Airbnbdata_R2 = pd.concat([Airbnbdata_R1,Airbnbdata],axis=1)
Airbnbdata_R2 = Airbnbdata_R2.drop([2],axis=1)

#Apply appropriate label
Airbnbdata_R2.columns = ['Type_of_Accomordation','Location_of_Accomodation','Info_Of_Accomordation', 'Feature','Total','Review_Ratings']
Airbnbdata_R2
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 0     Entire rental unit               Kailua-Kona
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# ..                    ...                      ...
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 297         Entire condo                  Honolulu
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...
# 2             Heavenly Hakalau: Oceanfront Cliff House
# 3        3 minutes walk to the beach 2BR/2BA Top floor
# 4                      Honolulu Hale with free parking
# ..                                                 ...
# 295  Unique opportunity to rent a New York style loft!
# 296                     LunaHouse In The Heart of Paia
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean
#
#                                         Feature  \
# 0      8 guests · 3 bedrooms · 5 beds · 3 baths
# 1      8 guests · 3 bedrooms · 3 beds · 2 baths
# 2      4 guests · 2 bedrooms · 2 beds · 2 baths
# 3      4 guests · 2 bedrooms · 3 beds · 2 baths
# 4       6 guests · 2 bedrooms · 2 beds · 1 bath
# ..                                          ...
# 295  6 guests · 2 bedrooms · 2 beds · 1.5 baths
# 296     4 guests · 2 bedrooms · 2 beds · 1 bath
# 297     5 guests · 2 bedrooms · 3 beds · 1 bath
# 298    4 guests · 2 bedrooms · 2 beds · 2 baths
# 299    6 guests · 2 bedrooms · 3 beds · 2 baths
#
#                                    Total      Review_Ratings
# 0                                ,&nbsp;  4.87 (187 reviews)
# 1    $332 CAD per night, originally $358  4.96 (217 reviews)
# 2                     $742 CAD per night  4.97 (154 reviews)
# 3                     $496 CAD per night  4.85 (171 reviews)
# 4                     $379 CAD per night  4.83 (124 reviews)
# ..                                   ...                 ...
# 295  $834 CAD per night, originally $904   4.72 (18 reviews)
# 296  $466 CAD per night, originally $504    5.0 (74 reviews)
# 297                   $419 CAD per night               empty
# 298                   $635 CAD per night    4.60 (5 reviews)
# 299                   $788 CAD per night   4.88 (52 reviews)
#
# [300 rows x 6 columns]

# %%
#Seprate the data of guest,bedrooms,beds,baths
#split feature columns data using "."
Airbnbdata_R3 = Airbnbdata_R2['Feature'].str.split('·', expand=True)

#Combine the newdataframe with original dataframe
Airbnbdata_R4 = pd.concat([Airbnbdata_R2,Airbnbdata_R3],axis=1)

#Drop the actual feature column
Airbnbdata_R4 = Airbnbdata_R4.drop(['Feature'],axis=1)

#Apply appropriate label
Airbnbdata_R4.columns = ['Type_of_Accomordation','Location_of_Accomodation','Info_Of_Accomordation','Total','Review_Ratings', 'No_of_guest','Rooms','Beds','Bath']
Airbnbdata_R4
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 0     Entire rental unit               Kailua-Kona
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# ..                    ...                      ...
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 297         Entire condo                  Honolulu
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...
# 2             Heavenly Hakalau: Oceanfront Cliff House
# 3        3 minutes walk to the beach 2BR/2BA Top floor
# 4                      Honolulu Hale with free parking
# ..                                                 ...
# 295  Unique opportunity to rent a New York style loft!
# 296                     LunaHouse In The Heart of Paia
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean
#
#                                    Total      Review_Ratings No_of_guest  \
# 0                                ,&nbsp;  4.87 (187 reviews)   8 guests
# 1    $332 CAD per night, originally $358  4.96 (217 reviews)   8 guests
# 2                     $742 CAD per night  4.97 (154 reviews)   4 guests
# 3                     $496 CAD per night  4.85 (171 reviews)   4 guests
# 4                     $379 CAD per night  4.83 (124 reviews)   6 guests
# ..                                   ...                 ...         ...
# 295  $834 CAD per night, originally $904   4.72 (18 reviews)   6 guests
# 296  $466 CAD per night, originally $504    5.0 (74 reviews)   4 guests
# 297                   $419 CAD per night               empty   5 guests
# 298                   $635 CAD per night    4.60 (5 reviews)   4 guests
# 299                   $788 CAD per night   4.88 (52 reviews)   6 guests
#
#             Rooms      Beds        Bath
# 0     3 bedrooms    5 beds      3 baths
# 1     3 bedrooms    3 beds      2 baths
# 2     2 bedrooms    2 beds      2 baths
# 3     2 bedrooms    3 beds      2 baths
# 4     2 bedrooms    2 beds       1 bath
# ..            ...       ...         ...
# 295   2 bedrooms    2 beds    1.5 baths
# 296   2 bedrooms    2 beds       1 bath
# 297   2 bedrooms    3 beds       1 bath
# 298   2 bedrooms    2 beds      2 baths
# 299   2 bedrooms    3 beds      2 baths
#
# [300 rows x 9 columns]

# %%
#Seprate the data of guest,bedrooms,beds,baths
#Split columns data using "."
Airbnbdata_R5 = Airbnbdata_R4['Review_Ratings'].str.split('(', expand=True)
Airbnbdata_R5

#Combine the newdataframe with original dataframe
Airbnbdata_R5 = pd.concat([Airbnbdata_R4,Airbnbdata_R5],axis=1)

#Drap the actual "Review_Rating" column
Airbnbdata_R5 = Airbnbdata_R5.drop(['Review_Ratings'],axis=1)
Airbnbdata_R5

#Apply appropriate label
Airbnbdata_R5.columns = ['Type_of_Accomordation','Location_of_Accomodation','Info_Of_Accomordation','Total', 'No_of_guest','Rooms','Beds','Bath','Ratings','Review']
Airbnbdata_R5
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 0     Entire rental unit               Kailua-Kona
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# ..                    ...                      ...
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 297         Entire condo                  Honolulu
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...
# 2             Heavenly Hakalau: Oceanfront Cliff House
# 3        3 minutes walk to the beach 2BR/2BA Top floor
# 4                      Honolulu Hale with free parking
# ..                                                 ...
# 295  Unique opportunity to rent a New York style loft!
# 296                     LunaHouse In The Heart of Paia
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean
#
#                                    Total No_of_guest         Rooms      Beds  \
# 0                                ,&nbsp;   8 guests    3 bedrooms    5 beds
# 1    $332 CAD per night, originally $358   8 guests    3 bedrooms    3 beds
# 2                     $742 CAD per night   4 guests    2 bedrooms    2 beds
# 3                     $496 CAD per night   4 guests    2 bedrooms    3 beds
# 4                     $379 CAD per night   6 guests    2 bedrooms    2 beds
# ..                                   ...         ...           ...       ...
# 295  $834 CAD per night, originally $904   6 guests    2 bedrooms    2 beds
# 296  $466 CAD per night, originally $504   4 guests    2 bedrooms    2 beds
# 297                   $419 CAD per night   5 guests    2 bedrooms    3 beds
# 298                   $635 CAD per night   4 guests    2 bedrooms    2 beds
# 299                   $788 CAD per night   6 guests    2 bedrooms    3 beds
#
#            Bath Ratings        Review
# 0       3 baths   4.87   187 reviews)
# 1       2 baths   4.96   217 reviews)
# 2       2 baths   4.97   154 reviews)
# 3       2 baths   4.85   171 reviews)
# 4        1 bath   4.83   124 reviews)
# ..          ...     ...           ...
# 295   1.5 baths   4.72    18 reviews)
# 296      1 bath    5.0    74 reviews)
# 297      1 bath   empty          None
# 298     2 baths   4.60     5 reviews)
# 299     2 baths   4.88    52 reviews)
#
# [300 rows x 10 columns]

# %%
#Remove ")" from review column 
Airbnbdata_R6 = Airbnbdata_R5["Review"].str.replace(')'," ")
Airbnbdata_R6 = pd.DataFrame(Airbnbdata_R6)

#Combine the dataframe
Airbnbdata_R6 = pd.concat([Airbnbdata_R5,Airbnbdata_R6],axis=1)

#Apply appropriate label
Airbnbdata_R6.columns = ['Type_of_Accomordation','Location_of_Accomodation','Info_Of_Accomordation','Total', 'No_of_guest','Rooms','Beds','Bath','Ratings','Dropreview','Review']

#Drop the actual column of "Dropreview"
Airbnbdata_R6 = Airbnbdata_R6.drop(['Dropreview'],axis=1)
Airbnbdata_R6
# Out:
# C:\Users\pooja\AppData\Local\Temp/ipykernel_21020/2482704012.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Airbnbdata_R6 = Airbnbdata_R5["Review"].str.replace(')'," ")
#     Type_of_Accomordation Location_of_Accomodation  \
# 0     Entire rental unit               Kailua-Kona
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# ..                    ...                      ...
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 297         Entire condo                  Honolulu
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...
# 2             Heavenly Hakalau: Oceanfront Cliff House
# 3        3 minutes walk to the beach 2BR/2BA Top floor
# 4                      Honolulu Hale with free parking
# ..                                                 ...
# 295  Unique opportunity to rent a New York style loft!
# 296                     LunaHouse In The Heart of Paia
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean
#
#                                    Total No_of_guest         Rooms      Beds  \
# 0                                ,&nbsp;   8 guests    3 bedrooms    5 beds
# 1    $332 CAD per night, originally $358   8 guests    3 bedrooms    3 beds
# 2                     $742 CAD per night   4 guests    2 bedrooms    2 beds
# 3                     $496 CAD per night   4 guests    2 bedrooms    3 beds
# 4                     $379 CAD per night   6 guests    2 bedrooms    2 beds
# ..                                   ...         ...           ...       ...
# 295  $834 CAD per night, originally $904   6 guests    2 bedrooms    2 beds
# 296  $466 CAD per night, originally $504   4 guests    2 bedrooms    2 beds
# 297                   $419 CAD per night   5 guests    2 bedrooms    3 beds
# 298                   $635 CAD per night   4 guests    2 bedrooms    2 beds
# 299                   $788 CAD per night   6 guests    2 bedrooms    3 beds
#
#            Bath Ratings        Review
# 0       3 baths   4.87   187 reviews
# 1       2 baths   4.96   217 reviews
# 2       2 baths   4.97   154 reviews
# 3       2 baths   4.85   171 reviews
# 4        1 bath   4.83   124 reviews
# ..          ...     ...           ...
# 295   1.5 baths   4.72    18 reviews
# 296      1 bath    5.0    74 reviews
# 297      1 bath   empty          None
# 298     2 baths   4.60     5 reviews
# 299     2 baths   4.88    52 reviews
#
# [300 rows x 10 columns]

# %%
#Seperate the value Total column by "," - so we can analysis that what are those extra values.
Airbnbdata_R7 = Airbnbdata_R6["Total"].str.split(',', expand=True)
Airbnbdata_R7 = pd.DataFrame(Airbnbdata_R7)

#Combine the dataframes
Airbnbdata_R7 = pd.concat([Airbnbdata_R6,Airbnbdata_R7],axis=1)
Airbnbdata_R7
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 0     Entire rental unit               Kailua-Kona
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# ..                    ...                      ...
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 297         Entire condo                  Honolulu
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...
# 2             Heavenly Hakalau: Oceanfront Cliff House
# 3        3 minutes walk to the beach 2BR/2BA Top floor
# 4                      Honolulu Hale with free parking
# ..                                                 ...
# 295  Unique opportunity to rent a New York style loft!
# 296                     LunaHouse In The Heart of Paia
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean
#
#                                    Total No_of_guest         Rooms      Beds  \
# 0                                ,&nbsp;   8 guests    3 bedrooms    5 beds
# 1    $332 CAD per night, originally $358   8 guests    3 bedrooms    3 beds
# 2                     $742 CAD per night   4 guests    2 bedrooms    2 beds
# 3                     $496 CAD per night   4 guests    2 bedrooms    3 beds
# 4                     $379 CAD per night   6 guests    2 bedrooms    2 beds
# ..                                   ...         ...           ...       ...
# 295  $834 CAD per night, originally $904   6 guests    2 bedrooms    2 beds
# 296  $466 CAD per night, originally $504   4 guests    2 bedrooms    2 beds
# 297                   $419 CAD per night   5 guests    2 bedrooms    3 beds
# 298                   $635 CAD per night   4 guests    2 bedrooms    2 beds
# 299                   $788 CAD per night   6 guests    2 bedrooms    3 beds
#
#            Bath Ratings        Review                   0                 1  \
# 0       3 baths   4.87   187 reviews                                 &nbsp;
# 1       2 baths   4.96   217 reviews   $332 CAD per night   originally $358
# 2       2 baths   4.97   154 reviews   $742 CAD per night              None
# 3       2 baths   4.85   171 reviews   $496 CAD per night              None
# 4        1 bath   4.83   124 reviews   $379 CAD per night              None
# ..          ...     ...           ...                 ...               ...
# 295   1.5 baths   4.72    18 reviews   $834 CAD per night   originally $904
# 296      1 bath    5.0    74 reviews   $466 CAD per night   originally $504
# 297      1 bath   empty          None  $419 CAD per night              None
# 298     2 baths   4.60     5 reviews   $635 CAD per night              None
# 299     2 baths   4.88    52 reviews   $788 CAD per night              None
#
#         2     3
# 0    None  None
# 1    None  None
# 2    None  None
# 3    None  None
# 4    None  None
# ..    ...   ...
# 295  None  None
# 296  None  None
# 297  None  None
# 298  None  None
# 299  None  None
#
# [300 rows x 14 columns]

# %%
#Apply appropriate label
Airbnbdata_R7.columns = ['Type_of_Accomordation','Location_of_Accomodation','Info_Of_Accomordation','Total', 'No_of_guest','Rooms','Beds','Bath','Ratings','Review','Total/Night','night','night1','night2']

#Remove unneccesary data from the table.
Airbnbdata_R7 = Airbnbdata_R7.drop(['Total','night','night1','night2'],axis=1)
Airbnbdata_R7
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 0     Entire rental unit               Kailua-Kona
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# ..                    ...                      ...
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 297         Entire condo                  Honolulu
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation No_of_guest  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...   8 guests
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...   8 guests
# 2             Heavenly Hakalau: Oceanfront Cliff House   4 guests
# 3        3 minutes walk to the beach 2BR/2BA Top floor   4 guests
# 4                      Honolulu Hale with free parking   6 guests
# ..                                                 ...         ...
# 295  Unique opportunity to rent a New York style loft!   6 guests
# 296                     LunaHouse In The Heart of Paia   4 guests
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen   5 guests
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH   4 guests
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean   6 guests
#
#             Rooms      Beds        Bath Ratings        Review  \
# 0     3 bedrooms    5 beds      3 baths   4.87   187 reviews
# 1     3 bedrooms    3 beds      2 baths   4.96   217 reviews
# 2     2 bedrooms    2 beds      2 baths   4.97   154 reviews
# 3     2 bedrooms    3 beds      2 baths   4.85   171 reviews
# 4     2 bedrooms    2 beds       1 bath   4.83   124 reviews
# ..            ...       ...         ...     ...           ...
# 295   2 bedrooms    2 beds    1.5 baths   4.72    18 reviews
# 296   2 bedrooms    2 beds       1 bath    5.0    74 reviews
# 297   2 bedrooms    3 beds       1 bath   empty          None
# 298   2 bedrooms    2 beds      2 baths   4.60     5 reviews
# 299   2 bedrooms    3 beds      2 baths   4.88    52 reviews
#
#             Total/Night
# 0
# 1    $332 CAD per night
# 2    $742 CAD per night
# 3    $496 CAD per night
# 4    $379 CAD per night
# ..                  ...
# 295  $834 CAD per night
# 296  $466 CAD per night
# 297  $419 CAD per night
# 298  $635 CAD per night
# 299  $788 CAD per night
#
# [300 rows x 10 columns]

# %%
#Replace blank with 0 in Total/Night column
Airbnbdata_R7 = Airbnbdata_R7.replace({'Total/Night' : { "" : 0}})
Airbnbdata_R7
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 0     Entire rental unit               Kailua-Kona
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# ..                    ...                      ...
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 297         Entire condo                  Honolulu
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation No_of_guest  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...   8 guests
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...   8 guests
# 2             Heavenly Hakalau: Oceanfront Cliff House   4 guests
# 3        3 minutes walk to the beach 2BR/2BA Top floor   4 guests
# 4                      Honolulu Hale with free parking   6 guests
# ..                                                 ...         ...
# 295  Unique opportunity to rent a New York style loft!   6 guests
# 296                     LunaHouse In The Heart of Paia   4 guests
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen   5 guests
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH   4 guests
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean   6 guests
#
#             Rooms      Beds        Bath Ratings        Review  \
# 0     3 bedrooms    5 beds      3 baths   4.87   187 reviews
# 1     3 bedrooms    3 beds      2 baths   4.96   217 reviews
# 2     2 bedrooms    2 beds      2 baths   4.97   154 reviews
# 3     2 bedrooms    3 beds      2 baths   4.85   171 reviews
# 4     2 bedrooms    2 beds       1 bath   4.83   124 reviews
# ..            ...       ...         ...     ...           ...
# 295   2 bedrooms    2 beds    1.5 baths   4.72    18 reviews
# 296   2 bedrooms    2 beds       1 bath    5.0    74 reviews
# 297   2 bedrooms    3 beds       1 bath   empty          None
# 298   2 bedrooms    2 beds      2 baths   4.60     5 reviews
# 299   2 bedrooms    3 beds      2 baths   4.88    52 reviews
#
#             Total/Night
# 0                     0
# 1    $332 CAD per night
# 2    $742 CAD per night
# 3    $496 CAD per night
# 4    $379 CAD per night
# ..                  ...
# 295  $834 CAD per night
# 296  $466 CAD per night
# 297  $419 CAD per night
# 298  $635 CAD per night
# 299  $788 CAD per night
#
# [300 rows x 10 columns]

# %%
#Remove special character
Airbnbdata_R7=Airbnbdata_R7.replace({'Location_of_Accomodation' : { ",":"","-":"","Ä":"a","Ê»":"e"," ":""}},regex=True)
Airbnbdata_R7
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 0     Entire rental unit                KailuaKona
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# ..                    ...                      ...
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 297         Entire condo                  Honolulu
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation No_of_guest  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...   8 guests
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...   8 guests
# 2             Heavenly Hakalau: Oceanfront Cliff House   4 guests
# 3        3 minutes walk to the beach 2BR/2BA Top floor   4 guests
# 4                      Honolulu Hale with free parking   6 guests
# ..                                                 ...         ...
# 295  Unique opportunity to rent a New York style loft!   6 guests
# 296                     LunaHouse In The Heart of Paia   4 guests
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen   5 guests
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH   4 guests
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean   6 guests
#
#             Rooms      Beds        Bath Ratings        Review  \
# 0     3 bedrooms    5 beds      3 baths   4.87   187 reviews
# 1     3 bedrooms    3 beds      2 baths   4.96   217 reviews
# 2     2 bedrooms    2 beds      2 baths   4.97   154 reviews
# 3     2 bedrooms    3 beds      2 baths   4.85   171 reviews
# 4     2 bedrooms    2 beds       1 bath   4.83   124 reviews
# ..            ...       ...         ...     ...           ...
# 295   2 bedrooms    2 beds    1.5 baths   4.72    18 reviews
# 296   2 bedrooms    2 beds       1 bath    5.0    74 reviews
# 297   2 bedrooms    3 beds       1 bath   empty          None
# 298   2 bedrooms    2 beds      2 baths   4.60     5 reviews
# 299   2 bedrooms    3 beds      2 baths   4.88    52 reviews
#
#             Total/Night
# 0                     0
# 1    $332 CAD per night
# 2    $742 CAD per night
# 3    $496 CAD per night
# 4    $379 CAD per night
# ..                  ...
# 295  $834 CAD per night
# 296  $466 CAD per night
# 297  $419 CAD per night
# 298  $635 CAD per night
# 299  $788 CAD per night
#
# [300 rows x 10 columns]

# %%
#Drop the row which contains  $0 or $1 price in Total/Night column
Airbnbdata_R7 = Airbnbdata_R7[Airbnbdata_R7["Total/Night"].str.contains("0") == False]
Airbnbdata_R8 = Airbnbdata_R7[Airbnbdata_R7["Total/Night"].str.contains("1") == False]
Airbnbdata_R8
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 1            Entire home                    Mounta
# 2        Entire bungalow                  Pepeekeo
# 3     Entire rental unit                     Kihei
# 4     Entire guest suite                  Honolulu
# 5           Entire condo                  Honolulu
# ..                    ...                      ...
# 294         Entire condo                   Kamuela
# 295          Entire loft                  Honolulu
# 296       Entire cottage                      Paia
# 298         Entire condo                     Kihei
# 299         Entire condo                      Laha
#
#                                  Info_Of_Accomordation No_of_guest  \
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...   8 guests
# 2             Heavenly Hakalau: Oceanfront Cliff House   4 guests
# 3        3 minutes walk to the beach 2BR/2BA Top floor   4 guests
# 4                      Honolulu Hale with free parking   6 guests
# 5                         2 Bedroom Condo With Parking   4 guests
# ..                                                 ...         ...
# 294  Mauna Lani condo with waterfall pool, hot tub ...   6 guests
# 295  Unique opportunity to rent a New York style loft!   6 guests
# 296                     LunaHouse In The Heart of Paia   4 guests
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH   4 guests
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean   6 guests
#
#             Rooms      Beds        Bath Ratings        Review  \
# 1     3 bedrooms    3 beds      2 baths   4.96   217 reviews
# 2     2 bedrooms    2 beds      2 baths   4.97   154 reviews
# 3     2 bedrooms    3 beds      2 baths   4.85   171 reviews
# 4     2 bedrooms    2 beds       1 bath   4.83   124 reviews
# 5     2 bedrooms    2 beds       1 bath   4.80   202 reviews
# ..            ...       ...         ...     ...           ...
# 294   2 bedrooms    3 beds      2 baths   4.77    26 reviews
# 295   2 bedrooms    2 beds    1.5 baths   4.72    18 reviews
# 296   2 bedrooms    2 beds       1 bath    5.0    74 reviews
# 298   2 bedrooms    2 beds      2 baths   4.60     5 reviews
# 299   2 bedrooms    3 beds      2 baths   4.88    52 reviews
#
#             Total/Night
# 1    $332 CAD per night
# 2    $742 CAD per night
# 3    $496 CAD per night
# 4    $379 CAD per night
# 5    $397 CAD per night
# ..                  ...
# 294  $528 CAD per night
# 295  $834 CAD per night
# 296  $466 CAD per night
# 298  $635 CAD per night
# 299  $788 CAD per night
#
# [150 rows x 10 columns]

# %%
#Store Airbnb_r8(revison8) into actual AB_Data variable
AB_Data = Airbnbdata_R8

# %%
#Store Csv file with cleaned data
AB_Data.to_csv('C:/Users/pooja/OneDrive/Desktop/AirBnb - Web Scraping & Data Analysis/Airbnb_FE_Data.csv')
