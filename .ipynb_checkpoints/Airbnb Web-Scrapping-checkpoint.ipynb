# %% [markdown]
# ### Install webscraping Library

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Let's Scrap Airbnb Website

# %%
# Creating a fuction to collect listing data from first page
def get_listings(search_page):
    answer = requests.get(search_page, timeout=5)
    content = answer.content
    soup = BeautifulSoup(content, 'html.parser')
    listings = soup.find_all('div', 'cm4lcvy dir dir-ltr')
    return listings

# %%
#To simplify the Scrapping process
#I entered date,no of people and destination in website 

#Below URL with Destination:Hawai Date:Aug26 to Sep:5 No_Of People-4 
#https://www.airbnb.ca/s/Hawaii--United-States/homes?place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&query=Hawaii%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&source=structured_search_input_header&search_type=filter_change&checkin=2022-08-26&checkout=2022-09-06&adults=4

#lets use the above url for scrapping
airbnb_url = 'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click'

# %%
# Add the URl to the function to het the data in html format 
listings = get_listings(airbnb_url)

# %%
#Check the scrap data 
print(listings)
# Out:
# [<div class="cm4lcvy dir dir-ltr" role="group"><a aria-labelledby="title_7651691" class="l8au1ct dir dir-ltr" href="/rooms/7651691?adults=4&amp;check_in=2022-08-26&amp;check_out=2022-09-06&amp;previous_page_section_name=1000&amp;federated_search_id=2548e800-d63e-4ffc-b71d-4c9e1367f6cf" lang="en" rel="noopener noreferrer" target="listing_7651691"></a><div class="m28cx3m dir dir-ltr"><div class="cza9200 cf0wwk1 cccwndf cof42p7 c1ex7ql7 dir dir-ltr" style="--media-container_border-radius:var(--i-g-gvoq)"><div class="_1mx6kqf" style="background:var(--d-nc-lt-s);--dls-basecard-padding-top:66.6667%"><div class="_1szwzht"><div class="_v0gz4uz" style="--dls-liteimage-padding-top:66.6667%"><div class="_4626ulj"><picture><source media="(max-width: 743px)" srcset="https://a0.muscache.com/im/pictures/72a1c236-b44b-4f12-bb3c-2f99b27e72e0.jpg?im_w=720 1x"/><source media="(min-width: 743.1px) and (max-width: 1127px)" srcset="https://a0.muscache.com/im/pictures/72a1c236-b44b-4f12-bb3c-2f99b27e72e0.jpg?im_w=720 1x"/><source media="(min-width: 1127.1px) and (max-width: 1439px)" srcset="https://a0.muscache.com/im/pictures/72a1c236-b44b-4f12-bb3c-2f99b27e72e0.jpg?im_w=720 1x"/><source media="(min-width: 1439.1px)" srcset="https://a0.muscache.com/im/pictures/72a1c236-b44b-4f12-bb3c-2f99b27e72e0.jpg?im_w=720 1x"/><img alt="" aria-hidden="true" class="_1cb9q3xq" data-original-uri="https://a0.muscache.com/im/pictures/72a1c236-b44b-4f12-bb3c-2f99b27e72e0.jpg?im_w=720" elementtiming="LCP-target" src="https://a0.muscache.com/im/pictures/72a1c236-b44b-4f12-bb3c-2f99b27e72e0.jpg?im_w=720" style="object-fit:cover"/></picture><div class="_10xjrv2u" style="background-image:url(https://a0.muscache.com/im/pictures/72a1c236-b44b-4f12-bb3c-2f99b27e72e0.jpg?im_w=720);background-size:cover"></div></div></div></div></div><div class="o1mwbk2f dir dir-ltr" style="--media-overlay_top-row-padding:var(--fgg-f-l-a)"><div class="t1vo9cyh dir dir-ltr"><div><div class="fcg8kp6 dir dir-ltr" style="--formatted-badge_background-color:rgba(255, 255, 255, 0.95);--formatted-badge_border:0.5px solid rgba(0, 0, 0, 0.2);--formatted-badge_color:#222222"><div class="t1oq1m17 dir dir-ltr">SUPERHOST</div></div></div></div><div class="m1uacxyo dir dir-ltr"><div class="nhc5psg ni0gafq dir dir-ltr"><button aria-label="Previous image" class="_1e67a0v" type="button"><span class="_3hmsj"><svg aria-hidden="true" focusable="false" role="presentation" style="display:block;fill:none;height:12px;width:12px;stroke:currentColor;stroke-width:4;overflow:visible" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="m20 28-11.29289322-11.2928932c-.39052429-.3905243-.39052429-1.0236893 0-1.4142136l11.29289322-11.2928932"></path></g></svg></span></button></div><div class="nhc5psg n1f034oj dir dir-ltr"><button aria-label="Next image" class="_1e67a0v" type="button"><span class="_3hmsj"><svg aria-hidden="true" focusable="false" role="presentation" style="display:block;fill:none;height:12px;width:12px;stroke:currentColor;stroke-width:4;overflow:visible" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="m12 4 11.2928932 11.2928932c.3905243.3905243.3905243 1.0236893 0 1.4142136l-11.2928932 11.2928932"></path></g></svg></span></button></div></div><div class="b1aww0y7 dir dir-ltr"></div></div></div></div><div class="idt4x4 dir dir-ltr"><div class="td9wtjk dir dir-ltr"><div class="kc26pza dir dir-ltr"><div class="cuu4odx c1frjvtt dir dir-ltr" style="--margin-bottom:var(--h-x-sf-jw)"><div class="mj1p6c8 dir dir-ltr">Entire rental unit in Kailua-Kona</div></div><div class="c1bx80b8 dir dir-ltr"><span class="ts5gl90 tl3qa0j t1nzedvd dir dir-ltr" id="title_7651691" lang="en" style="--title_font-weight:var(--e-y-j-d-v-j);--title_num-lines:1">★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rated ★</span></div></div></div><div class="s6xnzsn dir dir-ltr" style="--margin-top:11px;--horizontal-separator_width:32px"></div><div class="i1wgresd dir dir-ltr" style="--margin-top ...

# %%
#lets scrap the data based on css class
#The Below way we can extract data in different column so required less cleaning at the end
#store all the data in a dictionary with headings

def extract_basic_features(listing_html):
    
    features_dict = {}
    
    #If data available then store in below format
    try:
        listing_Location = listing_html.find("div", {"class": "cuu4odx c1frjvtt dir dir-ltr"}).text 
   
    #if data not available then write "Empty" 
    except:
        listing_Location = 'empty'
        
    try:
        Listing_Name = listing_html.find("div", {"class": "c1bx80b8 dir dir-ltr"}).text
    except:
        Listing_Name = 'empty'
    
    try:
        Features = listing_html.find("div", {"class": "i1wgresd dir dir-ltr"}).text
    except:
        Features = 'empty'
        
    try:
        Price = listing_html.find("span", {"class": "a8jt5op dir dir-ltr"}).text
    except:
        Price = 'empty'
    
    try:
        Rating_Review = listing_html.find("div", {"class": "sglmc5a dir dir-ltr"}).text
    except:
        Rating_Review = 'empty'
        
    
    features_dict['listing_Location'] = listing_Location
    features_dict['Listing_Name'] = Listing_Name
    features_dict['Features'] = Features
    features_dict['Price'] = Price
    features_dict['Rating_Review'] = Rating_Review
    
    return features_dict

# %%
# Create a fuction which collects all the URL of 15 different pages.
def build_urls(main_url, listings_per_page=20, pages_per_location=15):
    url_list = []
    for i in range(pages_per_location):
        offset = listings_per_page * i
        url_pagination = main_url + f'&items_offset={offset}'
        url_list.append(url_pagination)
    
    return url_list

# %%
# Add scrapping website URL in function
url_list = build_urls(airbnb_url)

# %%
# let's check the URL List for all 15 Pages
url_list
# Out:
# ['https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=0',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=20',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=40',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=60',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=80',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=100',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=120',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=140',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=160',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=180',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=200',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=220',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=240',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=260',
#  'https://www.airbnb.ca/s/Hawaii--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Hawaii%2C%20United%20States&place_id=ChIJBeB5Twbb_3sRKIbMdNKCd0s&checkin=2022-08-26&checkout=2022-09-06&adults=4&source=structured_search_input_header&search_type=autocomplete_click&items_offset=280']

# %%
# Add the get_listing fuction and and collect all the listing data from each page
def process_search_pages(url_list):
    features_list = []
    for page in url_list:
        listings = get_listings(page)
        for listing in listings:
            features = extract_basic_features(listing)
            features_list.append(features)

    return features_list

# %%
#Add url list so we can see all the listing text
Airbnb_Data = process_search_pages(url_list)

# %%
#lets check all the feature of listings
Airbnb_Data
# Out:
# [{'listing_Location': 'Entire rental unit in Kailua-Kona',
#   'Listing_Name': '★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rated ★',
#   'Features': '8 guests · 3 bedrooms · 5 beds · 3 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.87\xa0(187 reviews)'},
#  {'listing_Location': 'Entire home in Mountain View',
#   'Listing_Name': 'A/C All Rms/WorkStations/Dishwasher AlohaHaleNohea',
#   'Features': '8 guests · 3 bedrooms · 3 beds · 2 baths',
#   'Price': '$332 CAD per night, originally $358',
#   'Rating_Review': '4.96\xa0(217 reviews)'},
#  {'listing_Location': 'Entire bungalow in Pepeekeo',
#   'Listing_Name': 'Heavenly Hakalau: Oceanfront Cliff House',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$742 CAD per night',
#   'Rating_Review': '4.97\xa0(154 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kihei',
#   'Listing_Name': '3 minutes walk to the beach 2BR/2BA Top floor',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$496 CAD per night',
#   'Rating_Review': '4.85\xa0(171 reviews)'},
#  {'listing_Location': 'Entire guest suite in Honolulu',
#   'Listing_Name': 'Honolulu Hale with free parking',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$379 CAD per night',
#   'Rating_Review': '4.83\xa0(124 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': '2 Bedroom Condo With Parking',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$397 CAD per night',
#   'Rating_Review': '4.80\xa0(202 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kihei',
#   'Listing_Name': 'Beautiful Oceanfront Condo',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$431 CAD per night',
#   'Rating_Review': '4.77\xa0(158 reviews)'},
#  {'listing_Location': 'Entire home in Keaau',
#   'Listing_Name': 'Paradise Energy House ✔ King Bed ✔ Self Check-In',
#   'Features': '7 guests · 2 bedrooms · 5 beds · 2 baths',
#   'Price': '$361 CAD per night',
#   'Rating_Review': '4.96\xa0(524 reviews)'},
#  {'listing_Location': 'Entire home in Volcano',
#   'Listing_Name': 'Private Volcano Golf and Country Club Home',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.85\xa0(346 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'STUNNING PENTHOUSE -  100FT TO BEACH - LEGAL!!',
#   'Features': '4 guests · 1 bedroom · 1 bed · 2 baths',
#   'Price': '$523 CAD per night',
#   'Rating_Review': '4.95\xa0(110 reviews)'},
#  {'listing_Location': 'Entire condo in Wailea-Makena',
#   'Listing_Name': 'HGTV Inspired Remodel! Ocean View & min. to beach!',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$765 CAD per night',
#   'Rating_Review': '4.95\xa0(192 reviews)'},
#  {'listing_Location': 'Entire home in Captain Cook',
#   'Listing_Name': 'Makai Hideaway',
#   'Features': '8 guests · 3 bedrooms · 8 beds · 3 baths',
#   'Price': '$452 CAD per night',
#   'Rating_Review': '4.86\xa0(166 reviews)'},
#  {'listing_Location': 'Entire rental unit in Maunaloa',
#   'Listing_Name': 'Molokai,Ocean View,2bedrooms,upstairs,NOT ON  MAUI',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$178 CAD per night, originally $199',
#   'Rating_Review': '4.68\xa0(166 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': 'Escape to Paradise at The Paki Maui',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$304 CAD per night',
#   'Rating_Review': '4.78\xa0(125 reviews)'},
#  {'listing_Location': 'Entire rental unit in Honolulu',
#   'Listing_Name': 'Luana Waikiki Hotel - Ocean View & Modern style',
#   'Features': '4 guests · Studio · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.87\xa0(247 reviews)'},
#  {'listing_Location': 'Entire condo in Princeville',
#   'Listing_Name': 'Newly Renovated Northshore Condo',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 1.5 baths',
#   'Price': '$469 CAD per night',
#   'Rating_Review': '4.92\xa0(172 reviews)'},
#  {'listing_Location': 'Entire condo in Princeville',
#   'Listing_Name': 'OCEAN FRONT 2b/2ba Amazing Views! Princeville pool',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$638 CAD per night',
#   'Rating_Review': '4.95\xa0(204 reviews)'},
#  {'listing_Location': 'Entire condo in Kapaa',
#   'Listing_Name': 'BIG Ocean View, pool,Full Kitchen, King, WiFi, 203',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$493 CAD per night',
#   'Rating_Review': '4.87\xa0(149 reviews)'},
#  {'listing_Location': 'Entire condo in Kahuku',
#   'Listing_Name': 'RusticLuxe — Fully Custom Boss Cabin at Turtle Bay',
#   'Features': '4 guests · 1 bedroom · 2 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.91\xa0(271 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': '1/2 block to Beach OCEANVIEW in all rooms 1carport',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$842 CAD per night',
#   'Rating_Review': '4.74\xa0(171 reviews)'},
#  {'listing_Location': 'Entire home in Captain Cook',
#   'Listing_Name': 'Sweeping Views from a Striking Home with Balconies',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1.5 baths',
#   'Price': '$931 CAD per night',
#   'Rating_Review': '4.98\xa0(209 reviews)'},
#  {'listing_Location': 'Entire townhouse in Laie',
#   'Listing_Name': 'Sea Cliff House 2 - Oceanfront Home - 30-day stays',
#   'Features': '10 guests · 3 bedrooms · 7 beds · 2 baths',
#   'Price': '$1,203 CAD per night',
#   'Rating_Review': '4.87\xa0(190 reviews)'},
#  {'listing_Location': 'Entire guesthouse in Kihei',
#   'Listing_Name': "180' ocean views, heated pool at a villa by Wailea",
#   'Features': '4 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$1,109 CAD per night',
#   'Rating_Review': '4.97\xa0(310 reviews)'},
#  {'listing_Location': 'Entire condo in Kahuku',
#   'Listing_Name': 'RusticLuxe — Fully Custom Boss Cabin at Turtle Bay',
#   'Features': '4 guests · 1 bedroom · 2 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.91\xa0(271 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': '1/2 block to Beach OCEANVIEW in all rooms 1carport',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$842 CAD per night',
#   'Rating_Review': '4.74\xa0(171 reviews)'},
#  {'listing_Location': 'Entire condo in Princeville',
#   'Listing_Name': 'Newly Renovated Northshore Condo',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 1.5 baths',
#   'Price': '$469 CAD per night',
#   'Rating_Review': '4.92\xa0(172 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Ocean View, All New Renovation!',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$550 CAD per night',
#   'Rating_Review': '4.87\xa0(147 reviews)'},
#  {'listing_Location': 'Entire condo in Kauai',
#   'Listing_Name': 'Hidden Gem within Hanalei Bay 1 BR Condo',
#   'Features': '4 guests · 1 bedroom · 2 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.67\xa0(286 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Renovated 2 Bed/2 Bath Ocean Views from Lanai',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$441 CAD per night',
#   'Rating_Review': '4.71\xa0(173 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Kihei Oceanfront Beautiful 2 Bedroom Condo',
#   'Features': '5 guests · 2 bedrooms · 2 beds · 1.5 baths',
#   'Price': '$481 CAD per night',
#   'Rating_Review': '4.66\xa0(304 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': 'Newly Remodled Condo! Has it ALL!',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$597 CAD per night',
#   'Rating_Review': '4.78\xa0(94 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Spacious 4 BR, Ocean View w/Lanai, Sleeps 10',
#   'Features': '10 guests · 4 bedrooms · 7 beds · 2 baths',
#   'Price': '$1,053 CAD per night',
#   'Rating_Review': '4.91\xa0(97 reviews)'},
#  {'listing_Location': 'Entire home in Lahaina',
#   'Listing_Name': 'Renovated  Lahaina Plantation Home 3 BR/3 Baths',
#   'Features': '10 guests · 3 bedrooms · 3 beds · 3 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '5.0\xa0(69 reviews)'},
#  {'listing_Location': 'Entire condo in Wailuku',
#   'Listing_Name': 'Relax into Island Life at a Bamboo-Dotted Oceanfront Oasis',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$502 CAD per night',
#   'Rating_Review': '4.79\xa0(169 reviews)'},
#  {'listing_Location': 'Entire rental unit in Honolulu',
#   'Listing_Name': 'Last minute DEAL by Waikiki beach (All legal)',
#   'Features': '8 guests · 2 bedrooms · 5 beds · 2 baths',
#   'Price': '$704 CAD per night, originally $762',
#   'Rating_Review': '4.72\xa0(107 reviews)'},
#  {'listing_Location': 'Entire home in Pāhoa',
#   'Listing_Name': 'Open Loft Triangle Home. Ocean . Stars . Explore',
#   'Features': '6 guests · 1 bedroom · 7 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.75\xa0(259 reviews)'},
#  {'listing_Location': 'Entire condo in Wailuku',
#   'Listing_Name': 'Spacious Luxury Oceanfront - Fully Remodeled - Ocean Views',
#   'Features': '8 guests · 3 bedrooms · 5 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.94\xa0(143 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kahuku',
#   'Listing_Name': 'Hale Honu- Paradise at Turtle Bay',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$645 CAD per night',
#   'Rating_Review': '4.63\xa0(366 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': "Maui at it's best. Family ready.",
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$616 CAD per night',
#   'Rating_Review': '4.88\xa0(188 reviews)'},
#  {'listing_Location': 'Tiny homes in Volcano',
#   'Listing_Name': 'Tiki Tiny House at Volcano, Hawaii',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$322 CAD per night',
#   'Rating_Review': '4.84\xa0(212 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': "Maui at it's best. Family ready.",
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$616 CAD per night',
#   'Rating_Review': '4.88\xa0(188 reviews)'},
#  {'listing_Location': 'Entire condo in Wailuku',
#   'Listing_Name': 'Luxury Oceanfront ★ Designer Condo with Huge Views',
#   'Features': '6 guests · 2 bedrooms · 5 beds · 2 baths',
#   'Price': '$1,068 CAD per night',
#   'Rating_Review': '4.96\xa0(213 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Watch Rain Fall Inside Your Home Into The Indoor Water Feature. Amazing Entry Across An Indoor Pond. Expansive Unfettered Ocean Views',
#   'Features': '8 guests · 4 bedrooms · 5 beds · 3.5 baths',
#   'Price': '$3,299 CAD per night',
#   'Rating_Review': '4.73\xa0(88 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Beautiful 2BR Condo with view at Maui Vista Resort',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.88\xa0(219 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kihei',
#   'Listing_Name': 'Spacious condo close to beach',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$334 CAD per night',
#   'Rating_Review': '4.82\xa0(296 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kailua-Kona',
#   'Listing_Name': '☀ Modern, Tropical and Oceanside + AC & Free Pk ☀',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.85\xa0(361 reviews)'},
#  {'listing_Location': 'Entire condo in Kahuku',
#   'Listing_Name': 'RusticLuxe — Fully Custom Boss Cabin at Turtle Bay',
#   'Features': '4 guests · 1 bedroom · 2 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.91\xa0(271 reviews)'},
#  {'listing_Location': 'Entire home in Pāhoa',
#   'Listing_Name': 'Open Loft Triangle Home. Ocean . Stars . Explore',
#   'Features': '6 guests · 1 bedroom · 7 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.75\xa0(259 reviews)'},
#  {'listing_Location': 'Entire home in Kihei',
#   'Listing_Name': '8-403 Kamaole Sands**Newly Remodeled** Steps to Kamaole 3 Beach!',
#   'Features': '8 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.78\xa0(116 reviews)'},
#  {'listing_Location': 'Entire townhouse in Princeville',
#   'Listing_Name': 'Bungalow Indigo w/Beachgear',
#   'Features': '5 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$661 CAD per night',
#   'Rating_Review': '4.94\xa0(96 reviews)'},
#  {'listing_Location': 'Entire condo in Wailea-Makena',
#   'Listing_Name': 'Beautiful & Spacious Wailea Condo!! Walk to beach',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$725 CAD per night',
#   'Rating_Review': '4.90\xa0(191 reviews)'},
#  {'listing_Location': 'Entire guest suite in Kailua-Kona',
#   'Listing_Name': 'Kona dream vacation /POOL/AC/Great location',
#   'Features': '4 guests · Studio · 2 beds · 1 bath',
#   'Price': '$261 CAD per night',
#   'Rating_Review': '4.91\xa0(222 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kihei',
#   'Listing_Name': 'Great 1 Bdrm Across fr Beach OceanView!',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$365 CAD per night',
#   'Rating_Review': '4.87\xa0(334 reviews)'},
#  {'listing_Location': 'Entire home in Princeville',
#   'Listing_Name': "AC, Hot Tub & Plunge Pool! Steps to Queen's Bath!",
#   'Features': '16 guests · 4 bedrooms · 9 beds · 2.5 baths',
#   'Price': '$959 CAD per night, originally $1,211',
#   'Rating_Review': '4.75\xa0(97 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kihei',
#   'Listing_Name': 'Great value, nice Kihei condo',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$334 CAD per night',
#   'Rating_Review': '4.79\xa0(248 reviews)'},
#  {'listing_Location': 'Entire home in Honolulu',
#   'Listing_Name': 'STYLISH VILLA ! GREAT LOCATION ,CLEAN AND PRIVATE',
#   'Features': '16 guests · 5 bedrooms · 8 beds · 3 baths',
#   'Price': '$1,426 CAD per night',
#   'Rating_Review': '4.75\xa0(45 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Fun in the sun and beach at cozy Kihei get away!',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$499 CAD per night',
#   'Rating_Review': '4.89\xa0(240 reviews)'},
#  {'listing_Location': 'Entire townhouse in Princeville',
#   'Listing_Name': 'Natural Hawaiian Light and Tropical Breezes Fill Hale Indigo',
#   'Features': '5 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$702 CAD per night',
#   'Rating_Review': '4.90\xa0(84 reviews)'},
#  {'listing_Location': 'Entire home in Wailuku',
#   'Listing_Name': 'Charming Direct Oceanfront North Shore Beach House',
#   'Features': '8 guests · 4 bedrooms · 6 beds · 3 baths',
#   'Price': '$1,803 CAD per night',
#   'Rating_Review': '4.62\xa0(149 reviews)'},
#  {'listing_Location': 'Entire townhouse in Lahaina',
#   'Listing_Name': 'Say Aloha to a Luxurious Family Getaway',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$1,078 CAD per night',
#   'Rating_Review': '4.88\xa0(89 reviews)'},
#  {'listing_Location': 'Entire cottage in Captain Cook',
#   'Listing_Name': 'Honaunau Ocean View! Families Here!',
#   'Features': '6 guests · 3 bedrooms · 4 beds · 2 baths',
#   'Price': '$286 CAD per night, originally $312',
#   'Rating_Review': '4.84\xa0(60 reviews)'},
#  {'listing_Location': 'Entire home in Kaneohe',
#   'Listing_Name': 'Step Into Serenity',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$526 CAD per night',
#   'Rating_Review': '4.89\xa0(46 reviews)'},
#  {'listing_Location': 'Entire home in Honokaa',
#   'Listing_Name': 'Waiulililani at Waipio Valley, TA # 124-836-6592-01',
#   'Features': '6 guests · 3 bedrooms · 3 beds · 3 baths',
#   'Price': '$439 CAD per night, originally $502',
#   'Rating_Review': '4.83\xa0(92 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Townhouse steps away from ocean and pool',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$413 CAD per night',
#   'Rating_Review': '4.95\xa0(22 reviews)'},
#  {'listing_Location': 'Entire home in Papaikou',
#   'Listing_Name': 'New! - Oceanfront Paradise in Hilo w AC, Pool and Hot Tub. Remote Work!',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$577 CAD per night',
#   'Rating_Review': '5.0\xa0(3 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Waikoloa Resort Villa with Private Ocean Club',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$769 CAD per night',
#   'Rating_Review': '5.0\xa0(18 reviews)'},
#  {'listing_Location': 'Entire condo in Koloa',
#   'Listing_Name': 'Spacious Poipu Condo Sleeps 8',
#   'Features': '8 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$441 CAD per night',
#   'Rating_Review': '4.80\xa0(81 reviews)'},
#  {'listing_Location': 'Entire home in Keaau',
#   'Listing_Name': '3 bedroom house in Keaau near the volcano',
#   'Features': '8 guests · 3 bedrooms · 3 beds · 2 baths',
#   'Price': '$283 CAD per night',
#   'Rating_Review': '4.90\xa0(39 reviews)'},
#  {'listing_Location': 'Entire condo in Waimea',
#   'Listing_Name': 'Mauna Lani Golf Villa! Club Access, AC, Pool, Spa!',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$755 CAD per night',
#   'Rating_Review': '4.95\xa0(39 reviews)'},
#  {'listing_Location': 'Entire home in Naalehu',
#   'Listing_Name': 'Pool, Hot Tub, Japenese Pagoda & Gardens, Ocean Views',
#   'Features': '6 guests · 3 bedrooms · 3 beds · 2 baths',
#   'Price': '$405 CAD per night',
#   'Rating_Review': '4.84\xa0(31 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Spacious 2/2, doorstep to beaches and restaurants.',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$389 CAD per night, originally $426',
#   'Rating_Review': '5.0\xa0(10 reviews)'},
#  {'listing_Location': 'Entire townhouse in Waimea',
#   'Listing_Name': '❤️PiH❤️ISLANDS DELIGHT★Dual Master★Newly Renovated',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 2.5 baths',
#   'Price': '$631 CAD per night',
#   'Rating_Review': '5.0\xa0(19 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'The Mana Ohana - Ocean & Mtn. Views - sleeps 6-8',
#   'Features': '7 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$318 CAD per night, originally $347',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire guest suite in Honolulu',
#   'Listing_Name': 'Breezy 2BD ★PRIME LOCATION★ | Bright | Spotless',
#   'Features': '7 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$382 CAD per night',
#   'Rating_Review': '4.84\xa0(31 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Island Surf 311  Oceanview!! Steps from the Ocean. Air Purifier! Sanitized Cleaning! Watch the morning Surfers!',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$526 CAD per night',
#   'Rating_Review': '4.76\xa0(37 reviews)'},
#  {'listing_Location': 'Entire guesthouse in Kailua-Kona',
#   'Listing_Name': "Lani Wai Ka Napo'o",
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$438 CAD per night',
#   'Rating_Review': '4.84\xa0(73 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Kona Views',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$352 CAD per night',
#   'Rating_Review': '4.89\xa0(56 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Lovely 2 bedroom condo with ocean view',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$459 CAD per night',
#   'Rating_Review': '4.80\xa0(5 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Beautiful Oceanfront Two Bedroom Condo w/AC! #203',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$592 CAD per night',
#   'Rating_Review': '4.97\xa0(32 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Banyan 14th FL Sleeps SIX Guests w/ 1 Free Parking',
#   'Features': '6 guests · 1 bedroom · 3 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.22\xa0(85 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kihei',
#   'Listing_Name': 'Best condo in Kihei - great value!',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$334 CAD per night',
#   'Rating_Review': '4.73\xa0(283 reviews)'},
#  {'listing_Location': 'Entire rental unit in Honolulu',
#   'Listing_Name': 'Waikiki Penthouse Panorama Ocean/Moutain Views',
#   'Features': '8 guests · 2 bedrooms · 6 beds · 2 baths',
#   'Price': '$948 CAD per night',
#   'Rating_Review': '4.62\xa0(154 reviews)'},
#  {'listing_Location': 'Entire rental unit in Paia',
#   'Listing_Name': 'Maui Tropical House',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.73\xa0(284 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'SUGAR BEACH RETREAT: Ocean View: Steps to Beach',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$604 CAD per night',
#   'Rating_Review': '4.92\xa0(184 reviews)'},
#  {'listing_Location': 'Entire home in Laie',
#   'Listing_Name': 'Oceanfront Family Beach Retreat - Gated & Private',
#   'Features': '16 guests · 4 bedrooms · 11 beds · 4 baths',
#   'Price': '$2,136 CAD per night',
#   'Rating_Review': '4.79\xa0(51 reviews)'},
#  {'listing_Location': 'Entire condo in Princeville',
#   'Listing_Name': 'Airy Apt w/AC: Walk to Beach, 10 mins to Surf/Hike',
#   'Features': '4 guests · Studio · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.84\xa0(129 reviews)'},
#  {'listing_Location': 'Entire rental unit in Paia',
#   'Listing_Name': 'Hawaii Tropical Accommodations.',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.68\xa0(194 reviews)'},
#  {'listing_Location': 'Entire home in Hilo',
#   'Listing_Name': 'Hilo Hale Kai at Honolii Oceanfront',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$509 CAD per night',
#   'Rating_Review': '4.80\xa0(321 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kahuku',
#   'Listing_Name': 'Hale O Hoa- Paradise at Turtle Bay',
#   'Features': '4 guests · 1 bedroom · 1 bed · 1 bath',
#   'Price': '$535 CAD per night',
#   'Rating_Review': '4.80\xa0(235 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': 'Perfect Landing for You on Maui! T-046-692-0448-03',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$465 CAD per night, originally $498',
#   'Rating_Review': '4.82\xa0(233 reviews)'},
#  {'listing_Location': 'Entire home in Volcano',
#   'Listing_Name': 'House of Bonsai Vacation Rental',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$299 CAD per night, originally $327',
#   'Rating_Review': '4.97\xa0(428 reviews)'},
#  {'listing_Location': 'Entire condo in Wailuku',
#   'Listing_Name': 'Newly Remodeled Spectacular Oceanfront Condo!',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.88\xa0(227 reviews)'},
#  {'listing_Location': 'Entire guest suite in Naalehu',
#   'Listing_Name': '☀ Private Garden w/ Ocean Views → Green Sands ☀',
#   'Features': '4 guests · 1 bedroom · 1 bed · 1 bath',
#   'Price': '$373 CAD per night',
#   'Rating_Review': '4.91\xa0(375 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kihei',
#   'Listing_Name': 'Kamaole Beach Royale Entire 1 bedroom Aloha Apt',
#   'Features': '4 guests · 1 bedroom · 1 bed · 1 bath',
#   'Price': '$370 CAD per night, originally $399',
#   'Rating_Review': '4.80\xa0(237 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Paradise Awaits You! TRACY’S TROPICAL TREASURES #4',
#   'Features': '4 guests · Studio · 2 beds · 1 bath',
#   'Price': '$561 CAD per night',
#   'Rating_Review': '4.96\xa0(215 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Ocean View Superior Deluxe -  #200',
#   'Features': '5 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$713 CAD per night',
#   'Rating_Review': '4.79\xa0(267 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': "#1 IN KIHEI FOR 2021!TRACY'S TROPICAL TREASURES #3",
#   'Features': '4 guests · Studio · 2 beds · 1 bath',
#   'Price': '$513 CAD per night',
#   'Rating_Review': '4.95\xa0(202 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'SUITE DREAMS MAUI',
#   'Features': '4 guests · Studio · 2 beds · 1 bath',
#   'Price': '$531 CAD per night',
#   'Rating_Review': '4.88\xa0(282 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Romantic Bliss Maui',
#   'Features': '4 guests · Studio · 2 beds · 1 bath',
#   'Price': '$507 CAD per night',
#   'Rating_Review': '4.73\xa0(389 reviews)'},
#  {'listing_Location': 'Entire rental unit in Waimea',
#   'Listing_Name': 'Hale Malino at The Palm Villas at Mauna Lani',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$532 CAD per night',
#   'Rating_Review': '5.0\xa0(24 reviews)'},
#  {'listing_Location': 'Entire home in Pāhoa',
#   'Listing_Name': 'Tropical Big Island Getaway, Pahoa Hawaii, Hilo',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$174 CAD per night',
#   'Rating_Review': '4.84\xa0(46 reviews)'},
#  {'listing_Location': 'Entire home in Waimea',
#   'Listing_Name': 'OCEANFRONT 118 Puako - Hale Aloha',
#   'Features': '5 guests · 2 bedrooms · 2 beds · 1.5 baths',
#   'Price': '$960 CAD per night',
#   'Rating_Review': '5.0\xa0(13 reviews)'},
#  {'listing_Location': 'Entire guest suite in Pāhoa',
#   'Listing_Name': 'Adorable 2 bedroom- 3 blocks from ocean',
#   'Features': '8 guests · 2 bedrooms · 5 beds · 1 bath',
#   'Price': '$153 CAD per night, originally $167',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Waiʻanae',
#   'Listing_Name': 'Gardens and Rainbows!',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$151 CAD per night, originally $180',
#   'Rating_Review': '4.70\xa0(64 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Kona Paradise with Wide Ocean View @Royal Kahili',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.88\xa0(103 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Dragon Makai Hale',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 3 baths',
#   'Price': '$367 CAD per night',
#   'Rating_Review': '4.99\xa0(69 reviews)'},
#  {'listing_Location': 'Entire townhouse in Kamuela',
#   'Listing_Name': 'Affordable Luxury @ Magical Mauna Lani!',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$526 CAD per night',
#   'Rating_Review': '4.94\xa0(121 reviews)'},
#  {'listing_Location': 'Entire villa in Pāhoa',
#   'Listing_Name': 'Lava Flow House Pool Ocean View Kehena Beach w A/C',
#   'Features': '9 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$1,254 CAD per night, originally $1,355',
#   'Rating_Review': '5.0\xa0(33 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Kona Beach House',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$520 CAD per night',
#   'Rating_Review': '4.78\xa0(116 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua Kona',
#   'Listing_Name': 'Kona Pacific B409',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 3 baths',
#   'Price': '$519 CAD per night',
#   'Rating_Review': '4.80\xa0(15 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Oceanview on Golf Course 3 Pools Air',
#   'Features': '6 guests · 3 bedrooms · 5 beds · 3 baths',
#   'Price': '$429 CAD per night',
#   'Rating_Review': '4.86\xa0(14 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'THE MAUKA SUITE @ THE WAIKIKI BANYAN',
#   'Features': '4 guests · 1 bedroom · 3 beds · 1 bath',
#   'Price': '$448 CAD per night',
#   'Rating_Review': '4.75\xa0(29 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Large 2/2 penthouse with views in Waikoloa',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$580 CAD per night',
#   'Rating_Review': '4.93\xa0(14 reviews)'},
#  {'listing_Location': 'Entire bungalow in Captain Cook',
#   'Listing_Name': "Miloli'i Beach Bungalow, LLC",
#   'Features': '6 guests · 2 bedrooms · 2 beds · 1.5 baths',
#   'Price': '$200 CAD per night',
#   'Rating_Review': '4.88\xa0(33 reviews)'},
#  {'listing_Location': 'Entire home in Haleiwa',
#   'Listing_Name': 'Sunset Villa',
#   'Features': '6 guests · 3 bedrooms · 4 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.98\xa0(40 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Beautifully Remodeled 2 BR 2 BA & Stunning Views',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$304 CAD per night',
#   'Rating_Review': '5.0\xa0(20 reviews)'},
#  {'listing_Location': 'Entire home in Honolulu',
#   'Listing_Name': 'NEW▶Mountain RV-NO.7▶Open Free parking!',
#   'Features': '6 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.91\xa0(23 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Beach Resort',
#   'Listing_Name': 'Lush Tropical Oasis at Waikoloa Shores, Big Island',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$456 CAD per night',
#   'Rating_Review': '4.94\xa0(18 reviews)'},
#  {'listing_Location': 'Entire cottage in Captain Cook',
#   'Listing_Name': 'Honaunau Ocean View! Families Here!',
#   'Features': '6 guests · 3 bedrooms · 4 beds · 2 baths',
#   'Price': '$286 CAD per night, originally $312',
#   'Rating_Review': '4.84\xa0(60 reviews)'},
#  {'listing_Location': 'Entire cottage in Molokai',
#   'Listing_Name': 'Oceanfront/View 2BR Cottage, WiFi, Sunsets, Pool',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$413 CAD per night',
#   'Rating_Review': '5.0\xa0(17 reviews)'},
#  {'listing_Location': 'Entire townhouse in Maunaloa',
#   'Listing_Name': 'Best Oceanfront Location on West Molokai, not Maui',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$390 CAD per night',
#   'Rating_Review': '4.91\xa0(22 reviews)'},
#  {'listing_Location': 'Entire townhouse in Waimea',
#   'Listing_Name': '❤️PiH❤️ Island Song Villa ★ Renovated ★ Bikes ★',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2.5 baths',
#   'Price': '$623 CAD per night',
#   'Rating_Review': '4.88\xa0(24 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua',
#   'Listing_Name': 'Beach Front Family Condo at famous Lymans Cove',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$378 CAD per night',
#   'Rating_Review': '4.53\xa0(80 reviews)'},
#  {'listing_Location': 'Entire villa in Kapolei',
#   'Listing_Name': "Ko'Olina Resort-Private Vacation Villa",
#   'Features': '7 guests · 2 bedrooms · 3 beds · 2.5 baths',
#   'Price': '$746 CAD per night',
#   'Rating_Review': '4.93\xa0(29 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Halia Hale',
#   'Features': '6 guests · 3 bedrooms · 3 beds · 2 baths',
#   'Price': '$749 CAD per night',
#   'Rating_Review': '4.96\xa0(104 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Waikoloa Resort Villa with Private Ocean Club',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$769 CAD per night',
#   'Rating_Review': '5.0\xa0(18 reviews)'},
#  {'listing_Location': 'Entire rental unit in Honolulu',
#   'Listing_Name': 'One block to Waikiki Beach',
#   'Features': '6 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$306 CAD per night',
#   'Rating_Review': '4.29\xa0(30 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Na Hale O Keauhou H5 is a spacious 2-bedroom & 2-1/2 bath townhome',
#   'Features': '5 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$471 CAD per night',
#   'Rating_Review': '4.89\xa0(9 reviews)'},
#  {'listing_Location': 'Entire home in Waimea',
#   'Listing_Name': 'New Centrally Located Waimea Home on Big Island',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.99\xa0(67 reviews)'},
#  {'listing_Location': 'Private room in Keaau',
#   'Listing_Name': 'Upstairs bachelor Suite ( W-Ocean View)',
#   'Features': '6 guests · 1 bedroom · 3 beds · 1 private bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.84\xa0(182 reviews)'},
#  {'listing_Location': 'Entire rental unit in Honolulu',
#   'Listing_Name': 'Waikiki Banyan Tree *Oceanview * FREE Parking! King Bed',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.93\xa0(27 reviews)'},
#  {'listing_Location': 'Entire home in Hilo',
#   'Listing_Name': 'Aloha Falls Sanctuary. Peaceful Waterfall Paradise',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$602 CAD per night',
#   'Rating_Review': '4.90\xa0(85 reviews)'},
#  {'listing_Location': 'Entire condo in Kahuku',
#   'Listing_Name': 'NEWLY RENOVATED (2021) Turtle Bay Haven!',
#   'Features': '6 guests · 1 bedroom · 4 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.87\xa0(54 reviews)'},
#  {'listing_Location': 'Entire condo in Koloa',
#   'Listing_Name': 'Spacious Poipu Condo Sleeps 8',
#   'Features': '8 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$441 CAD per night',
#   'Rating_Review': '4.80\xa0(81 reviews)'},
#  {'listing_Location': 'Entire guesthouse in Kailua-Kona',
#   'Listing_Name': "Lani Wai Ka Napo'o",
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$438 CAD per night',
#   'Rating_Review': '4.84\xa0(73 reviews)'},
#  {'listing_Location': 'Entire home in Volcano',
#   'Listing_Name': 'A/C All Rms/WorkStation&Dishwasher AlohaHaleNohea2',
#   'Features': '6 guests · 3 bedrooms · 3 beds · 2 baths',
#   'Price': '$429 CAD per night',
#   'Rating_Review': '4.97\xa0(172 reviews)'},
#  {'listing_Location': 'Entire home in Naalehu',
#   'Listing_Name': 'Pool, Hot Tub, Japenese Pagoda & Gardens, Ocean Views',
#   'Features': '6 guests · 3 bedrooms · 3 beds · 2 baths',
#   'Price': '$405 CAD per night',
#   'Rating_Review': '4.84\xa0(31 reviews)'},
#  {'listing_Location': 'Entire home in Hilo',
#   'Listing_Name': 'NEW with AC ☆Somewhere Over Rainbow Loft ♥ Hilo',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 1.5 baths',
#   'Price': '$298 CAD per night',
#   'Rating_Review': '4.93\xa0(75 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua Kona',
#   'Listing_Name': 'Kona Isle C28. Corner Unit, 2nd Floor, Ocean Views, & Air Conditioning!',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$336 CAD per night',
#   'Rating_Review': '4.80\xa0(5 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Kona Makai 3-305',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$329 CAD per night',
#   'Rating_Review': '4.68\xa0(19 reviews)'},
#  {'listing_Location': 'Entire guesthouse in Haiku-Pauwela',
#   'Listing_Name': 'Maile Bungalow- County Licensed',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$466 CAD per night',
#   'Rating_Review': '4.92\xa0(115 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Kolea 8A at Waikoloa Beach, Hawaii',
#   'Features': '6 guests · 3 bedrooms · 4 beds · 3 baths',
#   'Price': '$1,224 CAD per night',
#   'Rating_Review': '5.0\xa0(20 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'STEPS FROM THE BEACH! 2-Bedroom, Brand-New Remodel',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$572 CAD per night, originally $626',
#   'Rating_Review': '5.0\xa0(17 reviews)'},
#  {'listing_Location': 'Farm stay in Pāhoa',
#   'Listing_Name': 'Farmhouse at Hawaiian Retreat',
#   'Features': '6 guests · 1 bedroom · 3 beds · 1 bath',
#   'Price': '$108 CAD per night, originally $115',
#   'Rating_Review': '4.63\xa0(109 reviews)'},
#  {'listing_Location': 'Entire condo in Kahuku',
#   'Listing_Name': 'NEWLY RENOVATED (2021) Turtle Bay Haven!',
#   'Features': '6 guests · 1 bedroom · 4 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.87\xa0(54 reviews)'},
#  {'listing_Location': 'Entire home in Hawi',
#   'Listing_Name': 'Custom Home on 10 acres with sweeping ocean views',
#   'Features': '8 guests · 3 bedrooms · 4 beds · 3 baths',
#   'Price': '$645 CAD per night',
#   'Rating_Review': '4.96\xa0(55 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Beautiful Top Floor Oceanfront Condo with AC! #415',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$584 CAD per night',
#   'Rating_Review': '5.0\xa0(21 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$635 CAD per night',
#   'Rating_Review': '4.60\xa0(5 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Spectacular water front view-2 bedroom/2 bath',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.94\xa0(17 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Oceanview Old Hawaiian Ranch House',
#   'Features': '6 guests · 3 bedrooms · 4 beds · 2.5 baths',
#   'Price': '$733 CAD per night',
#   'Rating_Review': '5.0\xa0(37 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Beach Resort',
#   'Listing_Name': 'Lush Tropical Oasis at Waikoloa Shores, Big Island',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$456 CAD per night',
#   'Rating_Review': '4.94\xa0(18 reviews)'},
#  {'listing_Location': 'Entire home in Pāhoa',
#   'Listing_Name': 'Kalapana Beach Haven',
#   'Features': '9 guests · 3 bedrooms · 5 beds · 4 baths',
#   'Price': '$962 CAD per night, originally $1,034',
#   'Rating_Review': '5.0\xa0(65 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Beach Villas (Ocean View) Sleeps 5',
#   'Features': '5 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$396 CAD per night',
#   'Rating_Review': '4.81\xa0(37 reviews)'},
#  {'listing_Location': 'Entire rental unit in Princeville',
#   'Listing_Name': 'Adventures in Paradise!',
#   'Features': '5 guests · 2 bedrooms · 5 beds · 2 baths',
#   'Price': '$442 CAD per night',
#   'Rating_Review': '4.80\xa0(47 reviews)'},
#  {'listing_Location': 'Entire home in Pāhoa',
#   'Listing_Name': 'Hale Melemele',
#   'Features': '7 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$226 CAD per night, originally $253',
#   'Rating_Review': '4.69\xa0(183 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Toast the Sunset in a Dreamy Island Penthouse Loft',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '5.0\xa0(111 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Beautifully UPGRADED Ocean View Condo Walk 2 Beach',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$592 CAD per night',
#   'Rating_Review': '5.0\xa0(40 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'NEWLY REMODELED!! 2 bedroom 2 bath condo, Maui, HI',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$361 CAD per night',
#   'Rating_Review': '4.85\xa0(79 reviews)'},
#  {'listing_Location': 'Entire home in Ewa Beach',
#   'Listing_Name': 'Ewa Sands',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$500 CAD per night',
#   'Rating_Review': '4.74\xa0(104 reviews)'},
#  {'listing_Location': 'Entire rental unit in Honolulu',
#   'Listing_Name': 'City lights Waikiki ($7,500 monthly)',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$649 CAD per night',
#   'Rating_Review': '4.76\xa0(87 reviews)'},
#  {'listing_Location': 'Entire cottage in Maui County',
#   'Listing_Name': 'Ocean View Cottage. Island Retreat.',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$502 CAD per night',
#   'Rating_Review': '4.93\xa0(29 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Kona Makai 3-305',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$329 CAD per night',
#   'Rating_Review': '4.68\xa0(19 reviews)'},
#  {'listing_Location': 'Entire home in Waiohinu',
#   'Listing_Name': 'Dragonfly Lodge, a Tropical Retreat House',
#   'Features': '7 guests · 4 bedrooms · 6 beds · 3 baths',
#   'Price': '$455 CAD per night, originally $487',
#   'Rating_Review': '4.96\xa0(108 reviews)'},
#  {'listing_Location': 'Entire cottage in Captain Cook',
#   'Listing_Name': 'NANAINA COTTAGE. JUNGLE LOVERS DREAM',
#   'Features': '4 guests · 1 bedroom · 4 beds · 1.5 baths',
#   'Price': '$350 CAD per night, originally $374',
#   'Rating_Review': '4.79\xa0(110 reviews)'},
#  {'listing_Location': 'Entire home in Hilo',
#   'Listing_Name': 'Cozy Ocean-view home w/AC near town, Rainbow Falls',
#   'Features': '7 guests · 3 bedrooms · 4 beds · 2 baths',
#   'Price': '$504 CAD per night',
#   'Rating_Review': '5.0\xa0(62 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': '=Free Parking!= Renovated 1Bedroom in East Waikiki',
#   'Features': '5 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$353 CAD per night',
#   'Rating_Review': '4.70\xa0(124 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Beautiful Top Floor Oceanfront Condo with AC! #421',
#   'Features': '5 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$624 CAD per night',
#   'Rating_Review': '4.95\xa0(37 reviews)'},
#  {'listing_Location': 'Entire cottage in Kailua-Kona',
#   'Listing_Name': "Foster's Ohia Hale",
#   'Features': '5 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$324 CAD per night',
#   'Rating_Review': '4.95\xa0(97 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Beach Front Luxury in Makena',
#   'Features': '5 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$1,670 CAD per night',
#   'Rating_Review': '5.0\xa0(7 reviews)'},
#  {'listing_Location': 'Entire rental unit in Kaunakakai',
#   'Listing_Name': 'Molokai sunsets',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$190 CAD per night, originally $213',
#   'Rating_Review': '4.69\xa0(49 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Stunning Ocean Sunset Views from Private Lanai',
#   'Features': '4 guests · 1 bedroom · 2 beds · 2 baths',
#   'Price': '$369 CAD per night',
#   'Rating_Review': '5.0\xa0(41 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Oceanfront Luxury at a Discount!',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$526 CAD per night',
#   'Rating_Review': '4.76\xa0(30 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Gorgeous sunsets, golf course and ocean views',
#   'Features': '4 guests · 2 bedrooms · 2.5 baths',
#   'Price': '$294 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire home in Honomu',
#   'Listing_Name': 'Private House Ocean/Mountain Views No Cleaning Fee',
#   'Features': '8 guests · 2 bedrooms · 6 beds · 2 baths',
#   'Price': '$330 CAD per night, originally $413',
#   'Rating_Review': '4.94\xa0(86 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Paradise at a reasonable price Unit #101',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$285 CAD per night',
#   'Rating_Review': '4.72\xa0(50 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua Kona',
#   'Listing_Name': 'Lovely Kona Plaza Beach Condo | Lanai, AC, Modern Kitchen | Pool, Grills',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$409 CAD per night',
#   'Rating_Review': '4.75\xa0(8 reviews)'},
#  {'listing_Location': 'Entire condo in Wailuku',
#   'Listing_Name': 'Spectacular luxury modern oceanfront best condo',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$692 CAD per night',
#   'Rating_Review': '5.0\xa0(11 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': "Kona Ali'i Village Home",
#   'Features': '5 guests · 3 bedrooms · 3 beds · 2 baths',
#   'Price': '$669 CAD per night',
#   'Rating_Review': '4.85\xa0(27 reviews)'},
#  {'listing_Location': 'Entire home in Pāhoa',
#   'Listing_Name': 'Kehena Hideaway Luxury Home',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$902 CAD per night',
#   'Rating_Review': '5.0\xa0(10 reviews)'},
#  {'listing_Location': 'Entire home in Naalehu',
#   'Listing_Name': 'Hale Malulani, Private Estate With Ocean Views!',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': ',&nbsp;',
#   'Rating_Review': '4.99\xa0(88 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': '2 Bedroom PentHouse Ocean Views in Waikiki',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$595 CAD per night',
#   'Rating_Review': '4.45\xa0(62 reviews)'},
#  {'listing_Location': 'Entire home in Kamuela',
#   'Listing_Name': 'Hale Kohola',
#   'Features': '6 guests · 3 bedrooms · 4 beds · 1 bath',
#   'Price': '$436 CAD per night, originally $472',
#   'Rating_Review': '4.94\xa0(153 reviews)'},
#  {'listing_Location': 'Entire home in Princeville',
#   'Listing_Name': 'Executive 3bd Home - Ocean views - cold A/C',
#   'Features': '6 guests · 3 bedrooms · 3 beds · 3.5 baths',
#   'Price': '$1,687 CAD per night',
#   'Rating_Review': '5.0\xa0(28 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': 'Great condo, great deals',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$557 CAD per night',
#   'Rating_Review': '4.20\xa0(5 reviews)'},
#  {'listing_Location': 'Entire home in Koloa',
#   'Listing_Name': 'Ka Nohona Pili Kai (living by the sea) Poipu Beach',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$580 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire home in Honolulu',
#   'Listing_Name': 'Beautiful Two Bedrooms, Gated & Private Entrance',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$761 CAD per night',
#   'Rating_Review': '4.86\xa0(81 reviews)'},
#  {'listing_Location': 'Entire home in Honolulu',
#   'Listing_Name': 'Beaches, hikes, R&R, and comfort await you.',
#   'Features': '5 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$592 CAD per night',
#   'Rating_Review': '5.0\xa0(6 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'KONA MAKAI OCEANFRONT SNORKEL,TENNIS, GYM, POOL',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$368 CAD per night',
#   'Rating_Review': '4.50\xa0(129 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Coastal Paradise at Peke\'s Ohana "New Listing"',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$412 CAD per night',
#   'Rating_Review': '4.80\xa0(5 reviews)'},
#  {'listing_Location': 'Entire condo in Hauula',
#   'Listing_Name': "Epic Views! 2 Story Beachfront @ Pat's at Punaluu!",
#   'Features': '6 guests · 3 bedrooms · 4 beds · 2 baths',
#   'Price': '$836 CAD per night',
#   'Rating_Review': '4.80\xa0(49 reviews)'},
#  {'listing_Location': 'Entire bungalow in Captain Cook',
#   'Listing_Name': "Miloli'i Beach Bungalow, LLC",
#   'Features': '6 guests · 2 bedrooms · 2 beds · 1.5 baths',
#   'Price': '$200 CAD per night',
#   'Rating_Review': '4.88\xa0(33 reviews)'},
#  {'listing_Location': 'Entire home in Volcano',
#   'Listing_Name': 'A/C All Rms/WorkStation&Dishwasher AlohaHaleNohea2',
#   'Features': '6 guests · 3 bedrooms · 3 beds · 2 baths',
#   'Price': '$429 CAD per night',
#   'Rating_Review': '4.97\xa0(172 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Wailea condominium, ocean view, 2 bed/2 bath',
# ...
#  {'listing_Location': 'Entire condo in Kapaʻa',
#   'Listing_Name': 'Paradise awaits! C-203 Dual Master Suite No Fees',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 3 baths',
#   'Price': '$911 CAD per night, originally $1,011',
#   'Rating_Review': '4.87\xa0(38 reviews)'},
#  {'listing_Location': 'Entire home in Maunaloa',
#   'Listing_Name': 'Beach Condo on Molokai',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$264 CAD per night',
#   'Rating_Review': '4.91\xa0(76 reviews)'},
#  {'listing_Location': 'Entire home in Kailua',
#   'Listing_Name': 'Beautiful Kailua Home, Near the Beach',
#   'Features': '5 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$396 CAD per night',
#   'Rating_Review': '4.82\xa0(67 reviews)'},
#  {'listing_Location': 'Entire rental unit in Laie',
#   'Listing_Name': 'Hale MOANA - 2bd, 2ba w/AC - Laie - 30 days',
#   'Features': '9 guests · 2 bedrooms · 8 beds · 2 baths',
#   'Price': '$450 CAD per night',
#   'Rating_Review': '4.95\xa0(153 reviews)'},
#  {'listing_Location': 'Entire rental unit in Honolulu',
#   'Listing_Name': 'One block to Waikiki Beach',
#   'Features': '6 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$306 CAD per night',
#   'Rating_Review': '4.29\xa0(30 reviews)'},
#  {'listing_Location': 'Entire vacation home in Waimea',
#   'Listing_Name': 'Mauna Lani Palm Villas D2 Quiet Unit Historic View',
#   'Features': '6 guests · 3 bedrooms · 4 beds · 2 baths',
#   'Price': '$733 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire guesthouse in Waimea',
#   'Listing_Name': 'Private, Waimea Ohana (Guest House)',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$321 CAD per night',
#   'Rating_Review': '4.97\xa0(117 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Casa Chilin-Waikoloa Beach Resort @ Fairway Villas',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$583 CAD per night',
#   'Rating_Review': '4.95\xa0(64 reviews)'},
#  {'listing_Location': 'Hotel room in Honolulu',
#   'Listing_Name': '33rd Floor LUXURY Suite Ala Moana Hotel by Waikiki',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 private bath',
#   'Price': '$321 CAD per night',
#   'Rating_Review': '4.91\xa0(55 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'OCEAN FRONT 2bd/2bth Twnhm  Sunset Views FREE A/C!',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$590 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire home in Honolulu',
#   'Listing_Name': 'Breathtaking ocean view, hot tub & pool',
#   'Features': '8 guests · 3 bedrooms · 4 beds · 3 baths',
#   'Price': '$1,373 CAD per night',
#   'Rating_Review': '5.0\xa0(3 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Cool and Comfortable, Home away from Home',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$275 CAD per night',
#   'Rating_Review': '4.92\xa0(24 reviews)'},
#  {'listing_Location': 'Entire condo in Wailuku',
#   'Listing_Name': 'Mermaid Cove Breathtaking Views Island Sands 506',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$700 CAD per night',
#   'Rating_Review': '4.79\xa0(19 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': 'Upgraded spacious condo, Aina Nalu Lahaina A109',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$514 CAD per night',
#   'Rating_Review': '4.85\xa0(102 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': "Uncle Bruce's Hale Aloha",
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$208 CAD per night',
#   'Rating_Review': '4.72\xa0(68 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Waikiki 8th floor w/2 Beds, Pool & Great City View',
#   'Features': '4 guests · Studio · 2 beds · 1 bath',
#   'Price': '$311 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire cottage in Honolulu',
#   'Listing_Name': "Mikaela's Cottage",
#   'Features': '6 guests · 3 bedrooms · 4 beds · 2 baths',
#   'Price': '$743 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'NEW 2-bedroom condo at Waikiki/Wifi/Kitchen',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$419 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Waimea',
#   'Listing_Name': 'Puako Beach Condo - Kid-Friendly Corner Unit 201',
#   'Features': '6 guests · 3 bedrooms · 4 beds · 2 baths',
#   'Price': '$400 CAD per night, originally $431',
#   'Rating_Review': '4.68\xa0(29 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': '15th FL Banyan Partial Ocean ｗ/ One Free Parking',
#   'Features': '8 guests · 1 bedroom · 4 beds · 1 bath',
#   'Price': '$417 CAD per night',
#   'Rating_Review': '4.74\xa0(39 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Kona Makai 5-201',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$390 CAD per night',
#   'Rating_Review': '4.80\xa0(5 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Ocean View Family Condo for a Getaway',
#   'Features': '6 guests · 1 bedroom · 3 beds · 1 bath',
#   'Price': '$628 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire cottage in Holualoa',
#   'Listing_Name': 'Kona Coffee Cottage in Holualoa',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$454 CAD per night',
#   'Rating_Review': '5.0\xa0(10 reviews)'},
#  {'listing_Location': 'Entire home in Ocean View',
#   'Listing_Name': 'Halfway to Kilauea, King suite, Long stays welcome',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$338 CAD per night',
#   'Rating_Review': '4.94\xa0(47 reviews)'},
#  {'listing_Location': 'Entire townhouse in Kailua-Kona',
#   'Listing_Name': 'Tropical Living in Oceanfront Resort 31',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$449 CAD per night',
#   'Rating_Review': '4.79\xa0(101 reviews)'},
#  {'listing_Location': 'Entire home in Waikoloa Village',
#   'Listing_Name': 'OceanView 3Bedroom *A/C*  Waikoloa Village house',
#   'Features': '6 guests · 3 bedrooms · 5 beds · 2 baths',
#   'Price': '$587 CAD per night, originally $631',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Casa Chilin-Waikoloa Beach Resort @ Fairway Villas',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$583 CAD per night',
#   'Rating_Review': '4.95\xa0(64 reviews)'},
#  {'listing_Location': 'Entire villa in Waimea',
#   'Listing_Name': 'Mauna Lani Resort Kulalani 1804 Secluded Villa with Class',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 3 baths',
#   'Price': '$579 CAD per night',
#   'Rating_Review': '4.84\xa0(32 reviews)'},
#  {'listing_Location': 'Entire condo in Waikoloa Village',
#   'Listing_Name': 'Romantic Beach Getaway F22 Walk to Beach & Golf',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$449 CAD per night',
#   'Rating_Review': '4.88\xa0(33 reviews)'},
#  {'listing_Location': 'Entire home in Honolulu',
#   'Listing_Name': 'Breathtaking ocean view, hot tub & pool',
#   'Features': '8 guests · 3 bedrooms · 4 beds · 3 baths',
#   'Price': '$1,373 CAD per night',
#   'Rating_Review': '5.0\xa0(3 reviews)'},
#  {'listing_Location': 'Resort room in Lahaina',
#   'Listing_Name': 'Honua Kai - 2BD/2BA - CORNER UNIT & LARGE BALCONY',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$1,166 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Waikiki at its Best - Marine Surf Studio',
#   'Features': '5 guests · Studio · 2 beds · 1 bath',
#   'Price': '$247 CAD per night, originally $277',
#   'Rating_Review': '4.86\xa0(78 reviews)'},
#  {'listing_Location': 'Entire guest suite in Honolulu',
#   'Listing_Name': 'All under heaven are of one family2',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$306 CAD per night',
#   'Rating_Review': '4.87\xa0(15 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Oceanfront 2 bed, 2 bath, full kitchen  with AC!',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$495 CAD per night, originally $541',
#   'Rating_Review': '5.0\xa0(8 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'Relaxing 2BD with Great Ocean Views 509',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$388 CAD per night',
#   'Rating_Review': '4.50\xa0(34 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Stunning Ocean Front Home',
#   'Features': '10 guests · 3 bedrooms · 8 beds · 3 baths',
#   'Price': '$2,029 CAD per night',
#   'Rating_Review': '4.91\xa0(34 reviews)'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Honu Kai Hale - Oceanfront home',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$1,086 CAD per night',
#   'Rating_Review': '4.91\xa0(65 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Waikiki Island Colony 1 Bdrm, 1702',
#   'Features': '4 guests · 1 bedroom · 3 beds · 1 bath',
#   'Price': '$288 CAD per night, originally $311',
#   'Rating_Review': '4.45\xa0(11 reviews)'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'BEAUTIFUL 1 BED/2 BATH AT MAUI KAMAOLE',
#   'Features': '4 guests · 1 bedroom · 2 beds · 2 baths',
#   'Price': '$380 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Wailuku',
#   'Listing_Name': 'Spectacular luxury modern oceanfront best condo',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$692 CAD per night',
#   'Rating_Review': '5.0\xa0(11 reviews)'},
#  {'listing_Location': 'Entire condo in Wailuku',
#   'Listing_Name': 'Direct Oceanfront - Kanai A Nalu 203 - 2BD/2BA',
#   'Features': '5 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$670 CAD per night',
#   'Rating_Review': '4.92\xa0(130 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Lovely 2 bedroom condo with awesome view',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$355 CAD per night',
#   'Rating_Review': '5.0\xa0(3 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Waikiki Banyan 1 bedroom Condo w/free Parking',
#   'Features': '6 guests · 1 bedroom · 3 beds · 1 bath',
#   'Price': '$370 CAD per night',
#   'Rating_Review': '5.0\xa0(3 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Waikiki 2 Bedroom w/ Covered Parking, Family Condo',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$566 CAD per night',
#   'Rating_Review': '4.74\xa0(43 reviews)'},
#  {'listing_Location': 'Entire guesthouse in Haiku-Pauwela',
#   'Listing_Name': 'HawaiianDreamTemple-2BRTropical Oasis BBPH20120004',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$808 CAD per night',
#   'Rating_Review': '4.79\xa0(104 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Views to Die For! Panoramic views in every room',
#   'Features': '7 guests · 2 bedrooms · 4 beds · 2 baths',
#   'Price': '$1,202 CAD per night',
#   'Rating_Review': '4.89\xa0(19 reviews)'},
#  {'listing_Location': 'Entire villa in Lahaina',
#   'Listing_Name': 'Villa 2423-24. Platinum level, remodeled townhouse features exquisite ocean views and lots of space',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 3 baths',
#   'Price': '$950 CAD per night, originally $1,040',
#   'Rating_Review': '4.95\xa0(20 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': 'Upgraded spacious condo, Aina Nalu Lahaina A109',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$514 CAD per night',
#   'Rating_Review': '4.85\xa0(102 reviews)'},
#  {'listing_Location': 'Entire bungalow in Lahaina',
#   'Listing_Name': 'Ka Hale Aloha (The Love Shack)',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': ',&nbsp;',
#   'Rating_Review': '5.0\xa0(60 reviews)'},
#  {'listing_Location': 'Entire cottage in Waimea',
#   'Listing_Name': 'The Reef House - 2 Bedroom Oceanfront Cottage',
#   'Features': '4 guests · 2 bedrooms · 2 baths',
#   'Price': '$1,315 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Remodeled Waikiki 2BR/1BA - central location',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$377 CAD per night',
#   'Rating_Review': '4.81\xa0(93 reviews)'},
#  {'listing_Location': 'Entire townhouse in Kihei',
#   'Listing_Name': "Newly remodeled 2B/2B  at Ma'alaea Surf Resort",
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$575 CAD per night',
#   'Rating_Review': '5.0\xa0(6 reviews)'},
#  {'listing_Location': 'Entire condo in Kailua-Kona',
#   'Listing_Name': 'Tropical Luxury –  Oceanfront Pool!!',
#   'Features': '4 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$321 CAD per night',
#   'Rating_Review': '4.74\xa0(117 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Finest Modern Banyan Waikiki Suite FREE Parking',
#   'Features': '7 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$448 CAD per night',
#   'Rating_Review': '4.75\xa0(109 reviews)'},
#  {'listing_Location': 'Entire condo in Princeville',
#   'Listing_Name': 'Beautiful spacious ocean and mountain view condo .',
#   'Features': '4 guests · 2 bedrooms · 1 bed · 2 baths',
#   'Price': '$492 CAD per night, originally $565',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'Waikiki Banyan Oceanview Modern Relaxation 4 guest',
#   'Features': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'Price': '$375 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire home in Kailua-Kona',
#   'Listing_Name': 'Custom ocean view 4/2 cottage in Kailua Kona',
#   'Features': '5 guests · 4 bedrooms · 4 beds · 2 baths',
#   'Price': '$658 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': 'Great condo, great deals',
#   'Features': '6 guests · 2 bedrooms · 4 beds · 1 bath',
#   'Price': '$557 CAD per night',
#   'Rating_Review': '4.20\xa0(5 reviews)'},
#  {'listing_Location': 'Entire condo in Kamuela',
#   'Listing_Name': 'Mauna Lani condo with waterfall pool, hot tub & tennis court',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$528 CAD per night, originally $600',
#   'Rating_Review': '4.77\xa0(26 reviews)'},
#  {'listing_Location': 'Entire loft in Honolulu',
#   'Listing_Name': 'Unique opportunity to rent a New York style loft!',
#   'Features': '6 guests · 2 bedrooms · 2 beds · 1.5 baths',
#   'Price': '$834 CAD per night, originally $904',
#   'Rating_Review': '4.72\xa0(18 reviews)'},
#  {'listing_Location': 'Entire cottage in Paia',
#   'Listing_Name': 'LunaHouse In The Heart of Paia',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'Price': '$466 CAD per night, originally $504',
#   'Rating_Review': '5.0\xa0(74 reviews)'},
#  {'listing_Location': 'Entire condo in Honolulu',
#   'Listing_Name': 'NEW 2-bedroom condo at Waikiki/Wifi/Kitchen',
#   'Features': '5 guests · 2 bedrooms · 3 beds · 1 bath',
#   'Price': '$419 CAD per night',
#   'Rating_Review': 'empty'},
#  {'listing_Location': 'Entire condo in Kihei',
#   'Listing_Name': 'OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH',
#   'Features': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'Price': '$635 CAD per night',
#   'Rating_Review': '4.60\xa0(5 reviews)'},
#  {'listing_Location': 'Entire condo in Lahaina',
#   'Listing_Name': 'Temp price drop! 180 deg views, 2b/2ba, on ocean',
#   'Features': '6 guests · 2 bedrooms · 3 beds · 2 baths',
#   'Price': '$788 CAD per night',
#   'Rating_Review': '4.88\xa0(52 reviews)'}]

# %%
# import pandas library
import pandas as pd

# %%
#convert the data into the dataframe
Airbnb_Data = pd.DataFrame(Airbnb_Data)
Airbnb_Data
# Out:
#                       listing_Location  \
# 0    Entire rental unit in Kailua-Kona
# 1         Entire home in Mountain View
# 2          Entire bungalow in Pepeekeo
# 3          Entire rental unit in Kihei
# 4       Entire guest suite in Honolulu
# ..                                 ...
# 295            Entire loft in Honolulu
# 296             Entire cottage in Paia
# 297           Entire condo in Honolulu
# 298              Entire condo in Kihei
# 299            Entire condo in Lahaina
#
#                                           Listing_Name  \
# 0    ★ Huge 3br/3ba ★ Amazing Ocean Views ★ Top rat...
# 1    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...
# 2             Heavenly Hakalau: Oceanfront Cliff House
# 3        3 minutes walk to the beach 2BR/2BA Top floor
# 4                      Honolulu Hale with free parking
# ..                                                 ...
# 295  Unique opportunity to rent a New York style loft!
# 296                     LunaHouse In The Heart of Paia
# 297        NEW 2-bedroom condo at Waikiki/Wifi/Kitchen
# 298     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH
# 299   Temp price drop! 180 deg views, 2b/2ba, on ocean
#
#                                        Features  \
# 0      8 guests · 3 bedrooms · 5 beds · 3 baths
# 1      8 guests · 3 bedrooms · 3 beds · 2 baths
# 2      4 guests · 2 bedrooms · 2 beds · 2 baths
# 3      4 guests · 2 bedrooms · 3 beds · 2 baths
# 4       6 guests · 2 bedrooms · 2 beds · 1 bath
# ..                                          ...
# 295  6 guests · 2 bedrooms · 2 beds · 1.5 baths
# 296     4 guests · 2 bedrooms · 2 beds · 1 bath
# 297     5 guests · 2 bedrooms · 3 beds · 1 bath
# 298    4 guests · 2 bedrooms · 2 beds · 2 baths
# 299    6 guests · 2 bedrooms · 3 beds · 2 baths
#
#                                    Price       Rating_Review
# 0                                ,&nbsp;  4.87 (187 reviews)
# 1    $332 CAD per night, originally $358  4.96 (217 reviews)
# 2                     $742 CAD per night  4.97 (154 reviews)
# 3                     $496 CAD per night  4.85 (171 reviews)
# 4                     $379 CAD per night  4.83 (124 reviews)
# ..                                   ...                 ...
# 295  $834 CAD per night, originally $904   4.72 (18 reviews)
# 296  $466 CAD per night, originally $504    5.0 (74 reviews)
# 297                   $419 CAD per night               empty
# 298                   $635 CAD per night    4.60 (5 reviews)
# 299                   $788 CAD per night   4.88 (52 reviews)
#
# [300 rows x 5 columns]

# %%
#lets Store the data into Csv file
Airbnb_Data.to_csv('C:/Users/pooja/OneDrive/Desktop/AirBnb - Web Scraping & Data Analysis/airbnb_WebScrap_data.csv')
