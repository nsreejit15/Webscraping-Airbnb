# %% [markdown]
# ## Data Analysis

# %%
#Import pandas library
import pandas as pd

# %%
#Read scrapped data file
#Open airbnb_hawai_data.csv file from folder
Airbnbdata = pd.read_csv(r'C:/Users/pooja/OneDrive/Desktop/AirBnb - Web Scraping & Data Analysis/Airbnb_FE_Data.csv').drop('Unnamed: 0',axis='columns')
Airbnbdata
# Out:
#     Type_of_Accomordation Location_of_Accomodation  \
# 0            Entire home                    Mounta
# 1        Entire bungalow                  Pepeekeo
# 2     Entire rental unit                     Kihei
# 3     Entire guest suite                  Honolulu
# 4           Entire condo                  Honolulu
# ..                    ...                      ...
# 145         Entire condo                   Kamuela
# 146          Entire loft                  Honolulu
# 147       Entire cottage                      Paia
# 148         Entire condo                     Kihei
# 149         Entire condo                      Laha
#
#                                  Info_Of_Accomordation No_of_guest  \
# 0    A/C All Rms/WorkStations/Dishwasher AlohaHaleN...   8 guests
# 1             Heavenly Hakalau: Oceanfront Cliff House   4 guests
# 2        3 minutes walk to the beach 2BR/2BA Top floor   4 guests
# 3                      Honolulu Hale with free parking   6 guests
# 4                         2 Bedroom Condo With Parking   4 guests
# ..                                                 ...         ...
# 145  Mauna Lani condo with waterfall pool, hot tub ...   6 guests
# 146  Unique opportunity to rent a New York style loft!   6 guests
# 147                     LunaHouse In The Heart of Paia   4 guests
# 148     OCEAN VIEW 2 BR 2 BATH PENTHOUSE KAM 2/3 BEACH   4 guests
# 149   Temp price drop! 180 deg views, 2b/2ba, on ocean   6 guests
#
#             Rooms      Beds        Bath Ratings        Review  \
# 0     3 bedrooms    3 beds      2 baths   4.96   217 reviews
# 1     2 bedrooms    2 beds      2 baths   4.97   154 reviews
# 2     2 bedrooms    3 beds      2 baths   4.85   171 reviews
# 3     2 bedrooms    2 beds       1 bath   4.83   124 reviews
# 4     2 bedrooms    2 beds       1 bath   4.80   202 reviews
# ..            ...       ...         ...     ...           ...
# 145   2 bedrooms    3 beds      2 baths   4.77    26 reviews
# 146   2 bedrooms    2 beds    1.5 baths   4.72    18 reviews
# 147   2 bedrooms    2 beds       1 bath    5.0    74 reviews
# 148   2 bedrooms    2 beds      2 baths   4.60     5 reviews
# 149   2 bedrooms    3 beds      2 baths   4.88    52 reviews
#
#             Total/Night
# 0    $332 CAD per night
# 1    $742 CAD per night
# 2    $496 CAD per night
# 3    $379 CAD per night
# 4    $397 CAD per night
# ..                  ...
# 145  $528 CAD per night
# 146  $834 CAD per night
# 147  $466 CAD per night
# 148  $635 CAD per night
# 149  $788 CAD per night
#
# [150 rows x 10 columns]

# %%
#Imports libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Check the datatype for airbnbdata
Airbnbdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Type_of_Accomordation     150 non-null    object
#  1   Location_of_Accomodation  150 non-null    object
#  2   Info_Of_Accomordation     150 non-null    object
#  3   No_of_guest               150 non-null    object
#  4   Rooms                     150 non-null    object
#  5   Beds                      150 non-null    object
#  6   Bath                      149 non-null    object
#  7   Ratings                   150 non-null    object
#  8   Review                    140 non-null    object
#  9   Total/Night               150 non-null    object
# dtypes: object(10)
# memory usage: 11.8+ KB

# %%
#1. How many Airbnb are available in different cities?
# In Which City has the highest % of accommodation available in Hawai

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20,20))
plt.title(" Airbnb in Hawai")
g = plt.pie(Airbnbdata.Location_of_Accomodation.value_counts(), labels=Airbnbdata.Location_of_Accomodation.value_counts().index,autopct='%1.1f%%', startangle=180, rotatelabels =True)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ### Finding 1. : Highest % of accomodation available in Kailua-Kona airbnb

# %%
#2. What is the highest type of accommodation available in Hawaii?

plt.figure(figsize=(19,7))
plt.title("Type of Accomodation in Hawai")
sns.countplot(Airbnbdata.Type_of_Accomordation, palette="muted")
plt.xticks(rotation = 60)
fig = plt.gcf()
plt.show()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Finding 2. : "Entire Condo" is highest type of accomodation available in hawai

# %%
#3. What type of stay available in different cities

plt.figure(figsize=(25,19))
plt.title("Type of Stays in different cities ")
sns.histplot(Airbnbdata, x=Airbnbdata.Location_of_Accomodation, hue=Airbnbdata.Type_of_Accomordation, multiple="stack",color="lightblue")
plt.xticks(rotation = 60)
plt.xlabel("City of Hawai")
plt.ylabel("Number of place")
# Out:
# Text(0, 0.5, 'Number of place')

# %% [markdown]
# ### Finding 3. : Different Citys have a different kinds of accommodation available.
#    ###### No Common type of stay available in all the cities but most of the Cities has "Entire Home" available

# %%
#After deciding city let's check what are the nominal price based on bedrooms and no of guest

# In order to do above analysis we have to create dataframe as below
Airbnbdata1 = Airbnbdata[['No_of_guest','Total/Night','Rooms']]
Airbnbdata1
# Out:
#     No_of_guest         Total/Night         Rooms
# 0     8 guests   $332 CAD per night   3 bedrooms
# 1     4 guests   $742 CAD per night   2 bedrooms
# 2     4 guests   $496 CAD per night   2 bedrooms
# 3     6 guests   $379 CAD per night   2 bedrooms
# 4     4 guests   $397 CAD per night   2 bedrooms
# ..          ...                 ...           ...
# 145   6 guests   $528 CAD per night   2 bedrooms
# 146   6 guests   $834 CAD per night   2 bedrooms
# 147   4 guests   $466 CAD per night   2 bedrooms
# 148   4 guests   $635 CAD per night   2 bedrooms
# 149   6 guests   $788 CAD per night   2 bedrooms
#
# [150 rows x 3 columns]

# %%
# Remove some of the text from column like(CAD, $, ",")
Airbnbdata1['Total/Night'] = Airbnbdata1['Total/Night'].str.replace('[CAD per night,$,,]','')
Airbnbdata1['No_of_guest'] = Airbnbdata1['No_of_guest'].str.replace('guests','')
Airbnbdata1['Rooms'] = Airbnbdata1['Rooms'].str.replace('[bedrooms,bedroom]','')
Airbnbdata1['Rooms'] = Airbnbdata1['Rooms'].str.replace('Stui','0')
Airbnbdata1
# Out:
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/4247893030.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   Airbnbdata1['Total/Night'] = Airbnbdata1['Total/Night'].str.replace('[CAD per night,$,,]','')
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/4247893030.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Airbnbdata1['Total/Night'] = Airbnbdata1['Total/Night'].str.replace('[CAD per night,$,,]','')
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/4247893030.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Airbnbdata1['No_of_guest'] = Airbnbdata1['No_of_guest'].str.replace('guests','')
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/4247893030.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   Airbnbdata1['Rooms'] = Airbnbdata1['Rooms'].str.replace('[bedrooms,bedroom]','')
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/4247893030.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Airbnbdata1['Rooms'] = Airbnbdata1['Rooms'].str.replace('[bedrooms,bedroom]','')
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/4247893030.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Airbnbdata1['Rooms'] = Airbnbdata1['Rooms'].str.replace('Stui','0')
#     No_of_guest Total/Night Rooms
# 0           8           332   3
# 1           4           742   2
# 2           4           496   2
# 3           6           379   2
# 4           4           397   2
# ..          ...         ...   ...
# 145         6           528   2
# 146         6           834   2
# 147         4           466   2
# 148         4           635   2
# 149         6           788   2
#
# [150 rows x 3 columns]

# %%
# Price_night are in object format
Airbnbdata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No_of_guest  150 non-null    object
#  1   Total/Night  150 non-null    object
#  2   Rooms        150 non-null    object
# dtypes: object(3)
# memory usage: 3.6+ KB

# %%
#convert price_night from object to int datatype
Airbnbdata1["Total/Night"] = Airbnbdata1["Total/Night"].astype(str).astype(int)
Airbnbdata1["No_of_guest"] = Airbnbdata1["No_of_guest"].astype(str).astype(int)
Airbnbdata1["Rooms"] = Airbnbdata1["Rooms"].astype(str).astype(int)
print(Airbnbdata1.dtypes)
# Out:
# No_of_guest    int32
# Total/Night    int32
# Rooms          int32
# dtype: object
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/2504544781.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Airbnbdata1["Total/Night"] = Airbnbdata1["Total/Night"].astype(str).astype(int)
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/2504544781.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Airbnbdata1["No_of_guest"] = Airbnbdata1["No_of_guest"].astype(str).astype(int)
# C:\Users\pooja\AppData\Local\Temp/ipykernel_2680/2504544781.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Airbnbdata1["Rooms"] = Airbnbdata1["Rooms"].astype(str).astype(int)

# %%
#sort the value based on guest size
Airbnbdata1 = Airbnbdata1.sort_values(by=['No_of_guest'], ascending=True)

# %%
#4. Is there any relation between price per night and the number of guests?

plt.style.use('fivethirtyeight')
plt.figure(figsize=(14,12))
sns.boxplot(y='Total/Night',x='No_of_guest',data = Airbnbdata1)
plt.title('Price Distribution based on guest size')
plt.show()

# %% [markdown]
# ### Finding 4. : Based on above analysis we can say that price are not dependent on the guestsize.

# %%
#5. What are the prices based on bedrooms and is there any relation between price and number of rooms

plt.style.use('fivethirtyeight')
plt.figure(figsize=(14,12))
sns.boxplot(y='Total/Night',x='Rooms',data = Airbnbdata1)
plt.title('Price Distribution based on guest size')
plt.show()

# %% [markdown]
# ### Finding 5. : After the analysis we can say that price are highly dependent on the bedrooms.
# ##### As the Bedroom Increases the prices are increases too.
